# %%
# !git clone https://github.com/ntua-el21050/bd3lms.git
# Out:
# Cloning into 'bd3lms'...
# remote: Enumerating objects: 1163, done.
# remote: Counting objects: 100% (426/426), done.
# remote: Compressing objects: 100% (199/199), done.
# remote: Total 1163 (delta 320), reused 292 (delta 226), pack-reused 737 (from 2)
# Receiving objects: 100% (1163/1163), 8.07 MiB | 17.66 MiB/s, done.
# Resolving deltas: 100% (729/729), done.

# %%
# %%capture
# !pip install -r bd3lms/requirements.txt

# %%
import subprocess
import re
from pathlib import Path

def run_main(overrides, timeout=None):
    """Run `python -u main.py ...` and return combined stdout/stderr text."""
    env = dict(os.environ)
    env.setdefault("HYDRA_FULL_ERROR", "1")
    cmd = [sys.executable, "-u", "bd3lms/main.py", *overrides]
    print("\n$", " ".join(cmd))
    proc = subprocess.run(
        cmd,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True,
        timeout=timeout,
        check=False,
        env=env,
    )
    print(proc.stdout[-4000:])  # tail for quick visibility
    if proc.returncode != 0:
        raise RuntimeError(f"Command failed with return code {proc.returncode}")
    return proc.stdout

_METRIC_PATTERNS = [
    # Key: value (some loggers print this)
    re.compile(r"val/ppl\s*[:=]\s*([0-9]+(?:\.[0-9]+)?(?:e[+-]?\d+)?)", re.IGNORECASE),
    re.compile(r"'val/ppl'\s*:\s*([0-9]+(?:\.[0-9]+)?(?:e[+-]?\d+)?)", re.IGNORECASE),

    # Lightning "rich" table row (note the unicode box character │)
    re.compile(r"val/ppl\s*[│|]\s*([0-9]+(?:\.[0-9]+)?(?:e[+-]?\d+)?)", re.IGNORECASE),
]

def extract_val_ppl(log_text: str):
    # First try line-based parse from the end (most reliable for tables)
    for line in reversed(log_text.splitlines()):
        if "val/ppl" in line.lower():
            m = re.search(r"val/ppl.*?([0-9]+(?:\.[0-9]+)?(?:e[+-]?\d+)?)", line, re.IGNORECASE)
            if m:
                return float(m.group(1))

    # Fallback: scan entire text with known patterns
    hits = []
    for pat in _METRIC_PATTERNS:
        hits.extend(pat.findall(log_text))
    return float(hits[-1]) if hits else None

def _small_loader_overrides(batch_size=8, num_workers=2):
    """Overrides needed to avoid huge default batch sizes on Colab."""
    return [
        f"loader.global_batch_size={batch_size}",
        f"loader.eval_global_batch_size={batch_size}",
        f"loader.batch_size={batch_size}",
        f"loader.eval_batch_size={batch_size}",
        f"loader.num_workers={num_workers}",
        "trainer.accumulate_grad_batches=1",
    ]

def train_run(run_name, algo, block_size=None, from_pretrained=None, max_steps=800, extra_overrides=None):
    """Train a model (optionally from a base checkpoint) and return the last.ckpt path."""
    save_dir = Path("/content/repro_runs") / run_name
    if save_dir.exists():
        shutil.rmtree(save_dir)
    save_dir.mkdir(parents=True, exist_ok=True)

    overrides = [
        "mode=eval",
        "data=lm1b-wrap",
        "data.cache_dir=/content/bd3lms/data",
        "data.streaming=true",
        "data.max_train_samples=5000",
        # For LM1B, validation uses the 'test' split in this codebase
        "model=tiny",
        "model.length=128",
        "model.attn_backend=sdpa",
        f"algo={algo}",
        "trainer.accelerator=gpu",
        "trainer.devices=1",
        "trainer.num_nodes=1",
        "trainer.precision=16-mixed",
        "trainer.num_sanity_val_steps=0",
        "trainer.log_every_n_steps=10",
        "trainer.val_check_interval=50",
        f"trainer.max_steps={max_steps}",
        "data.max_valid_samples=1000",
        "data.max_test_samples=1000",
        f"checkpointing.save_dir=/content/repro_runs/{run_name}",
        "checkpointing.resume_from_ckpt=false",
        "wandb=null",
    ]
    overrides.extend(_small_loader_overrides(batch_size=8, num_workers=2))
    if block_size is not None:
        overrides.append(f"block_size={block_size}")
    if from_pretrained is not None:
        overrides.append(f"training.from_pretrained={from_pretrained}")
    if extra_overrides:
        overrides.extend(extra_overrides)

    _ = run_main(overrides)
    ckpt = save_dir / "checkpoints" / "last.ckpt"
    if not ckpt.exists():
        raise FileNotFoundError(f"Expected checkpoint not found: {ckpt}")
    return str(ckpt)

def eval_run(algo, checkpoint_path, block_size=None, extra_overrides=None):
    """Evaluate perplexity (val/ppl) for a given checkpoint."""
    overrides = [
        "mode=ppl_eval",
        "data=lm1b-wrap",
        "data.cache_dir=/content/bd3lms/data",
        "data.streaming=true",
        # For LM1B, `get_dataloaders` maps validation to the 'test' split
        "data.max_test_samples=1000",
        "data.max_valid_samples=1000",
        "data.max_train_samples=1000",
        "+data.skip_samples=0",
        "model=tiny",
        "model.length=128",
        "model.attn_backend=sdpa",
        f"algo={algo}",
        f"eval.checkpoint_path={checkpoint_path}",
        "trainer.accelerator=gpu",
        "trainer.devices=1",
        "trainer.num_nodes=1",
        "trainer.precision=16-mixed",
        "trainer.num_sanity_val_steps=0",
        "wandb=null",
    ]
    overrides.extend(_small_loader_overrides(batch_size=8, num_workers=2))
    if block_size is not None:
        overrides.append(f"block_size={block_size}")
    if extra_overrides:
        overrides.extend(extra_overrides)

    log_text = run_main(overrides)
    ppl = extract_val_ppl(log_text)
    if ppl is None:
        raise ValueError("Could not parse val/ppl from output. Try increasing the log tail or printing full logs.")
    return ppl

# %%
import os
import shutil
import sys

results = []

bd3lm_base_run = "bd3lm_base_len128"
bd3lm_base_ckpt = train_run(
    bd3lm_base_run,
    algo="bd3lm",
    block_size=128,
    extra_overrides=[
        "training.resample=false",
        "algo.var_min=false",
        "algo.clip_search_widths=[]",
    ],
)

for Lprime in [16, 8, 4]:
    finetune_run = f"bd3lm_finetune_Lp{Lprime}"
    finetune_ckpt = train_run(
        finetune_run,
        algo="bd3lm",
        block_size=Lprime,
        from_pretrained=bd3lm_base_ckpt,
        extra_overrides=[
            "training.resample=true",
            "algo.var_min=false",
            "algo.clip_search_widths=[]",
        ],
    )
    ppl = eval_run(
        algo="bd3lm",
        checkpoint_path=finetune_ckpt,
        block_size=Lprime,
        extra_overrides=[
            "algo.var_min=false",
        ],
    )
    results.append({"model": "Block diffusion (BD3LM)", "block_size_Lprime": Lprime, "val_ppl": ppl})
# Out:
# $ /usr/bin/python3 -u bd3lms/main.py mode=eval data=lm1b-wrap data.cache_dir=/content/bd3lms/data data.streaming=true data.max_train_samples=5000 model=tiny model.length=128 model.attn_backend=sdpa algo=bd3lm trainer.accelerator=gpu trainer.devices=1 trainer.num_nodes=1 trainer.precision=16-mixed trainer.num_sanity_val_steps=0 trainer.log_every_n_steps=10 trainer.val_check_interval=50 trainer.max_steps=800 data.max_valid_samples=1000 data.max_test_samples=1000 checkpointing.save_dir=/content/repro_runs/bd3lm_base_len128 checkpointing.resume_from_ckpt=false wandb=null loader.global_batch_size=8 loader.eval_global_batch_size=8 loader.batch_size=8 loader.eval_batch_size=8 loader.num_workers=2 trainer.accumulate_grad_batches=1 block_size=128 training.resample=false algo.var_min=false algo.clip_search_widths=[]
# -------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 1 processes
# ----------------------------------------------------------------------------------------------------
#
# 2026-02-15 11:44:06.706145: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771155846.904062    3235 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771155846.956639    3235 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771155847.355201    3235 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771155847.355253    3235 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771155847.355257    3235 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771155847.355260    3235 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-02-15 11:44:07.395335: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type           | Params | Mode
# ----------------------------------------------------
# 0 | backbone | DIT            | 22.8 M | train
# 1 | noise    | LogLinearNoise | 0      | train
# ----------------------------------------------------
# 22.8 M    Trainable params
# 0         Non-trainable params
# 22.8 M    Total params
# 91.266    Total estimated model params size (MB)
# 110       Modules in train mode
# 0         Modules in eval mode
# /usr/local/lib/python3.12/dist-packages/torch/distributed/distributed_c10d.py:4631: UserWarning: No device id is provided via `init_process_group` or `barrier `. Using the current device set by the user.
#   warnings.warn(  # warn only once
# Epoch 0, global step 50: 'val/nll' reached 10.32397 (best 10.32397), saving model to '/content/repro_runs/bd3lm_base_len128/checkpoints/best.ckpt' as top 1
# Epoch 0, global step 100: 'val/nll' reached 10.16264 (best 10.16264), saving model to '/content/repro_runs/bd3lm_base_len128/checkpoints/best.ckpt' as top 1
# Epoch 1, global step 196: 'val/nll' reached 9.82773 (best 9.82773), saving model to '/content/repro_runs/bd3lm_base_len128/checkpoints/best.ckpt' as top 1
# Epoch 1, global step 246: 'val/nll' reached 9.48093 (best 9.48093), saving model to '/content/repro_runs/bd3lm_base_len128/checkpoints/best.ckpt' as top 1
# Epoch 2, global step 342: 'val/nll' reached 8.28396 (best 8.28396), saving model to '/content/repro_runs/bd3lm_base_len128/checkpoints/best.ckpt' as top 1
# Epoch 2, global step 392: 'val/nll' reached 7.44951 (best 7.44951), saving model to '/content/repro_runs/bd3lm_base_len128/checkpoints/best.ckpt' as top 1
# Epoch 3, global step 488: 'val/nll' reached 6.90902 (best 6.90902), saving model to '/content/repro_runs/bd3lm_base_len128/checkpoints/best.ckpt' as top 1
# Epoch 3, global step 538: 'val/nll' was not in top 1
# Epoch 4, global step 634: 'val/nll' was not in top 1
# Epoch 4, global step 684: 'val/nll' was not in top 1
# Epoch 5, global step 780: 'val/nll' was not in top 1
# `Trainer.fit` stopped: `max_steps=800` reached.
#
#
# $ /usr/bin/python3 -u bd3lms/main.py mode=eval data=lm1b-wrap data.cache_dir=/content/bd3lms/data data.streaming=true data.max_train_samples=5000 model=tiny model.length=128 model.attn_backend=sdpa algo=bd3lm trainer.accelerator=gpu trainer.devices=1 trainer.num_nodes=1 trainer.precision=16-mixed trainer.num_sanity_val_steps=0 trainer.log_every_n_steps=10 trainer.val_check_interval=50 trainer.max_steps=800 data.max_valid_samples=1000 data.max_test_samples=1000 checkpointing.save_dir=/content/repro_runs/bd3lm_finetune_Lp16 checkpointing.resume_from_ckpt=false wandb=null loader.global_batch_size=8 loader.eval_global_batch_size=8 loader.batch_size=8 loader.eval_batch_size=8 loader.num_workers=2 trainer.accumulate_grad_batches=1 block_size=16 training.from_pretrained=/content/repro_runs/bd3lm_base_len128/checkpoints/last.ckpt training.resample=true algo.var_min=false algo.clip_search_widths=[]
# vailable: False, using: 0 HPUs
# `Trainer(limit_train_batches=1.0)` was configured so 100% of the batches per epoch will be used..
# `Trainer(limit_val_batches=1.0)` was configured so 100% of the batches will be used..
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 1 processes
# ----------------------------------------------------------------------------------------------------
#
# 2026-02-15 11:50:13.362459: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771156213.380079    5020 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771156213.385139    5020 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771156213.402356    5020 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771156213.402384    5020 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771156213.402388    5020 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771156213.402390    5020 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-02-15 11:50:13.409021: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type           | Params | Mode
# ----------------------------------------------------
# 0 | backbone | DIT            | 22.8 M | train
# 1 | noise    | LogLinearNoise | 0      | train
# ----------------------------------------------------
# 22.8 M    Trainable params
# 0         Non-trainable params
# 22.8 M    Total params
# 91.266    Total estimated model params size (MB)
# 110       Modules in train mode
# 0         Modules in eval mode
# /usr/local/lib/python3.12/dist-packages/torch/distributed/distributed_c10d.py:4631: UserWarning: No device id is provided via `init_process_group` or `barrier `. Using the current device set by the user.
#   warnings.warn(  # warn only once
# Epoch 0, global step 50: 'val/nll' reached 7.13976 (best 7.13976), saving model to '/content/repro_runs/bd3lm_finetune_Lp16/checkpoints/best.ckpt' as top 1
# Epoch 0, global step 100: 'val/nll' reached 7.11762 (best 7.11762), saving model to '/content/repro_runs/bd3lm_finetune_Lp16/checkpoints/best.ckpt' as top 1
# Epoch 1, global step 196: 'val/nll' reached 7.11008 (best 7.11008), saving model to '/content/repro_runs/bd3lm_finetune_Lp16/checkpoints/best.ckpt' as top 1
# Epoch 2, global step 292: 'val/nll' was not in top 1
# Epoch 2, global step 342: 'val/nll' was not in top 1
# Epoch 3, global step 438: 'val/nll' was not in top 1
# Epoch 3, global step 488: 'val/nll' reached 7.03169 (best 7.03169), saving model to '/content/repro_runs/bd3lm_finetune_Lp16/checkpoints/best.ckpt' as top 1
# Epoch 4, global step 584: 'val/nll' was not in top 1
# Epoch 4, global step 634: 'val/nll' was not in top 1
# Epoch 5, global step 730: 'val/nll' was not in top 1
# Epoch 5, global step 780: 'val/nll' was not in top 1
# `Trainer.fit` stopped: `max_steps=800` reached.
#
#
# $ /usr/bin/python3 -u bd3lms/main.py mode=ppl_eval data=lm1b-wrap data.cache_dir=/content/bd3lms/data data.streaming=true data.max_test_samples=1000 data.max_valid_samples=1000 data.max_train_samples=1000 +data.skip_samples=0 model=tiny model.length=128 model.attn_backend=sdpa algo=bd3lm eval.checkpoint_path=/content/repro_runs/bd3lm_finetune_Lp16/checkpoints/last.ckpt trainer.accelerator=gpu trainer.devices=1 trainer.num_nodes=1 trainer.precision=16-mixed trainer.num_sanity_val_steps=0 wandb=null loader.global_batch_size=8 loader.eval_global_batch_size=8 loader.batch_size=8 loader.eval_batch_size=8 loader.num_workers=2 trainer.accumulate_grad_batches=1 block_size=16 algo.var_min=false
# oading checkpoint at 780
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/core/saving.py:195: Found keys that are not in the model state dict but in the checkpoint: ['sampling_eps_min', 'sampling_eps_max']
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# `Trainer(limit_train_batches=1.0)` was configured so 100% of the batches per epoch will be used..
# `Trainer(limit_val_batches=1.0)` was configured so 100% of the batches will be used..
# Seed set to 1
# [2026-02-15 11:54:23,984][dataloader][INFO] - Generating new data at: /content/bd3lms/data/lm1b_test_bs128_wrapped.dat
# [2026-02-15 11:54:23,984][dataloader][INFO] - streaming=True
#
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Map: 100%|██████████| 1000/1000 [00:00<00:00, 2014.26 examples/s]
# Map: 100%|██████████| 1000/1000 [00:00<00:00, 2008.53 examples/s]
#
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Map: 100%|██████████| 1000/1000 [00:00<00:00, 39476.92 examples/s]
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 1 processes
# ----------------------------------------------------------------------------------------------------
#
# 2026-02-15 11:57:08.303126: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771156628.320601    6698 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771156628.325684    6698 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771156628.339293    6698 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771156628.339314    6698 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771156628.339316    6698 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771156628.339320    6698 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-02-15 11:57:08.343525: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/connectors/data_connector.py:476: Your `val_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
# /usr/local/lib/python3.12/dist-packages/torch/distributed/distributed_c10d.py:4631: UserWarning: No device id is provided via `init_process_group` or `barrier `. Using the current device set by the user.
#   warnings.warn(  # warn only once
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val/bpd          │    10.167603492736816     │
# │          val/nll          │    7.0476460456848145     │
# │          val/ppl          │     1150.148193359375     │
# └───────────────────────────┴───────────────────────────┘
#
#
# $ /usr/bin/python3 -u bd3lms/main.py mode=eval data=lm1b-wrap data.cache_dir=/content/bd3lms/data data.streaming=true data.max_train_samples=5000 model=tiny model.length=128 model.attn_backend=sdpa algo=bd3lm trainer.accelerator=gpu trainer.devices=1 trainer.num_nodes=1 trainer.precision=16-mixed trainer.num_sanity_val_steps=0 trainer.log_every_n_steps=10 trainer.val_check_interval=50 trainer.max_steps=800 data.max_valid_samples=1000 data.max_test_samples=1000 checkpointing.save_dir=/content/repro_runs/bd3lm_finetune_Lp8 checkpointing.resume_from_ckpt=false wandb=null loader.global_batch_size=8 loader.eval_global_batch_size=8 loader.batch_size=8 loader.eval_batch_size=8 loader.num_workers=2 trainer.accumulate_grad_batches=1 block_size=8 training.from_pretrained=/content/repro_runs/bd3lm_base_len128/checkpoints/last.ckpt training.resample=true algo.var_min=false algo.clip_search_widths=[]
# ,  6824,  1012,   101])
# [2026-02-15 12:00:18,056][__main__][INFO] - Loading pretrained model from /content/repro_runs/bd3lm_base_len128/checkpoints/last.ckpt
# Loading checkpoint at 780
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# `Trainer(limit_train_batches=1.0)` was configured so 100% of the batches per epoch will be used..
# `Trainer(limit_val_batches=1.0)` was configured so 100% of the batches will be used..
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 1 processes
# ----------------------------------------------------------------------------------------------------
#
# 2026-02-15 12:00:20.006438: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771156820.024224    7579 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771156820.029211    7579 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771156820.042593    7579 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771156820.042617    7579 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771156820.042620    7579 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771156820.042623    7579 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-02-15 12:00:20.047699: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type           | Params | Mode
# ----------------------------------------------------
# 0 | backbone | DIT            | 22.8 M | train
# 1 | noise    | LogLinearNoise | 0      | train
# ----------------------------------------------------
# 22.8 M    Trainable params
# 0         Non-trainable params
# 22.8 M    Total params
# 91.266    Total estimated model params size (MB)
# 110       Modules in train mode
# 0         Modules in eval mode
# /usr/local/lib/python3.12/dist-packages/torch/distributed/distributed_c10d.py:4631: UserWarning: No device id is provided via `init_process_group` or `barrier `. Using the current device set by the user.
#   warnings.warn(  # warn only once
# Epoch 0, global step 50: 'val/nll' reached 7.03099 (best 7.03099), saving model to '/content/repro_runs/bd3lm_finetune_Lp8/checkpoints/best.ckpt' as top 1
# Epoch 0, global step 100: 'val/nll' was not in top 1
# Epoch 1, global step 196: 'val/nll' was not in top 1
# Epoch 2, global step 292: 'val/nll' was not in top 1
# Epoch 2, global step 342: 'val/nll' was not in top 1
# Epoch 3, global step 438: 'val/nll' was not in top 1
# Epoch 3, global step 488: 'val/nll' was not in top 1
# Epoch 4, global step 584: 'val/nll' was not in top 1
# Epoch 4, global step 634: 'val/nll' was not in top 1
# Epoch 5, global step 730: 'val/nll' was not in top 1
# Epoch 5, global step 780: 'val/nll' was not in top 1
# `Trainer.fit` stopped: `max_steps=800` reached.
#
#
# $ /usr/bin/python3 -u bd3lms/main.py mode=ppl_eval data=lm1b-wrap data.cache_dir=/content/bd3lms/data data.streaming=true data.max_test_samples=1000 data.max_valid_samples=1000 data.max_train_samples=1000 +data.skip_samples=0 model=tiny model.length=128 model.attn_backend=sdpa algo=bd3lm eval.checkpoint_path=/content/repro_runs/bd3lm_finetune_Lp8/checkpoints/last.ckpt trainer.accelerator=gpu trainer.devices=1 trainer.num_nodes=1 trainer.precision=16-mixed trainer.num_sanity_val_steps=0 wandb=null loader.global_batch_size=8 loader.eval_global_batch_size=8 loader.batch_size=8 loader.eval_batch_size=8 loader.num_workers=2 trainer.accumulate_grad_batches=1 block_size=8 algo.var_min=false
# oading checkpoint at 780
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/core/saving.py:195: Found keys that are not in the model state dict but in the checkpoint: ['sampling_eps_min', 'sampling_eps_max']
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# `Trainer(limit_train_batches=1.0)` was configured so 100% of the batches per epoch will be used..
# `Trainer(limit_val_batches=1.0)` was configured so 100% of the batches will be used..
# Seed set to 1
# [2026-02-15 12:04:15,930][dataloader][INFO] - Generating new data at: /content/bd3lms/data/lm1b_test_bs128_wrapped.dat
# [2026-02-15 12:04:15,930][dataloader][INFO] - streaming=True
#
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Map: 100%|██████████| 1000/1000 [00:00<00:00, 2378.39 examples/s]
# Map: 100%|██████████| 1000/1000 [00:00<00:00, 2368.46 examples/s]
#
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Map: 100%|██████████| 1000/1000 [00:00<00:00, 37406.39 examples/s]
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 1 processes
# ----------------------------------------------------------------------------------------------------
#
# 2026-02-15 12:06:54.922753: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771157214.940408    9409 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771157214.945543    9409 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771157214.959150    9409 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771157214.959174    9409 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771157214.959177    9409 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771157214.959179    9409 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-02-15 12:06:54.963235: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/connectors/data_connector.py:476: Your `val_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
# /usr/local/lib/python3.12/dist-packages/torch/distributed/distributed_c10d.py:4631: UserWarning: No device id is provided via `init_process_group` or `barrier `. Using the current device set by the user.
#   warnings.warn(  # warn only once
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val/bpd          │    10.074898719787598     │
# │          val/nll          │     6.983387470245361     │
# │          val/ppl          │    1078.5657958984375     │
# └───────────────────────────┴───────────────────────────┘
#
#
# $ /usr/bin/python3 -u bd3lms/main.py mode=eval data=lm1b-wrap data.cache_dir=/content/bd3lms/data data.streaming=true data.max_train_samples=5000 model=tiny model.length=128 model.attn_backend=sdpa algo=bd3lm trainer.accelerator=gpu trainer.devices=1 trainer.num_nodes=1 trainer.precision=16-mixed trainer.num_sanity_val_steps=0 trainer.log_every_n_steps=10 trainer.val_check_interval=50 trainer.max_steps=800 data.max_valid_samples=1000 data.max_test_samples=1000 checkpointing.save_dir=/content/repro_runs/bd3lm_finetune_Lp4 checkpointing.resume_from_ckpt=false wandb=null loader.global_batch_size=8 loader.eval_global_batch_size=8 loader.batch_size=8 loader.eval_batch_size=8 loader.num_workers=2 trainer.accumulate_grad_batches=1 block_size=4 training.from_pretrained=/content/repro_runs/bd3lm_base_len128/checkpoints/last.ckpt training.resample=true algo.var_min=false algo.clip_search_widths=[]
# ,  6824,  1012,   101])
# [2026-02-15 12:09:14,344][__main__][INFO] - Loading pretrained model from /content/repro_runs/bd3lm_base_len128/checkpoints/last.ckpt
# Loading checkpoint at 780
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# `Trainer(limit_train_batches=1.0)` was configured so 100% of the batches per epoch will be used..
# `Trainer(limit_val_batches=1.0)` was configured so 100% of the batches will be used..
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 1 processes
# ----------------------------------------------------------------------------------------------------
#
# 2026-02-15 12:09:16.306371: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771157356.323923   10218 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771157356.328894   10218 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771157356.342482   10218 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771157356.342505   10218 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771157356.342508   10218 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771157356.342510   10218 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-02-15 12:09:16.346709: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type           | Params | Mode
# ----------------------------------------------------
# 0 | backbone | DIT            | 22.8 M | train
# 1 | noise    | LogLinearNoise | 0      | train
# ----------------------------------------------------
# 22.8 M    Trainable params
# 0         Non-trainable params
# 22.8 M    Total params
# 91.266    Total estimated model params size (MB)
# 110       Modules in train mode
# 0         Modules in eval mode
# /usr/local/lib/python3.12/dist-packages/torch/distributed/distributed_c10d.py:4631: UserWarning: No device id is provided via `init_process_group` or `barrier `. Using the current device set by the user.
#   warnings.warn(  # warn only once
# Epoch 0, global step 50: 'val/nll' reached 7.04583 (best 7.04583), saving model to '/content/repro_runs/bd3lm_finetune_Lp4/checkpoints/best.ckpt' as top 1
# Epoch 0, global step 100: 'val/nll' was not in top 1
# Epoch 1, global step 196: 'val/nll' was not in top 1
# Epoch 2, global step 292: 'val/nll' was not in top 1
# Epoch 2, global step 342: 'val/nll' was not in top 1
# Epoch 3, global step 438: 'val/nll' was not in top 1
# Epoch 3, global step 488: 'val/nll' was not in top 1
# Epoch 4, global step 584: 'val/nll' was not in top 1
# Epoch 4, global step 634: 'val/nll' was not in top 1
# Epoch 5, global step 730: 'val/nll' was not in top 1
# Epoch 5, global step 780: 'val/nll' was not in top 1
# `Trainer.fit` stopped: `max_steps=800` reached.
#
#
# $ /usr/bin/python3 -u bd3lms/main.py mode=ppl_eval data=lm1b-wrap data.cache_dir=/content/bd3lms/data data.streaming=true data.max_test_samples=1000 data.max_valid_samples=1000 data.max_train_samples=1000 +data.skip_samples=0 model=tiny model.length=128 model.attn_backend=sdpa algo=bd3lm eval.checkpoint_path=/content/repro_runs/bd3lm_finetune_Lp4/checkpoints/last.ckpt trainer.accelerator=gpu trainer.devices=1 trainer.num_nodes=1 trainer.precision=16-mixed trainer.num_sanity_val_steps=0 wandb=null loader.global_batch_size=8 loader.eval_global_batch_size=8 loader.batch_size=8 loader.eval_batch_size=8 loader.num_workers=2 trainer.accumulate_grad_batches=1 block_size=4 algo.var_min=false
# oading checkpoint at 780
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/core/saving.py:195: Found keys that are not in the model state dict but in the checkpoint: ['sampling_eps_min', 'sampling_eps_max']
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# `Trainer(limit_train_batches=1.0)` was configured so 100% of the batches per epoch will be used..
# `Trainer(limit_val_batches=1.0)` was configured so 100% of the batches will be used..
# Seed set to 1
# [2026-02-15 12:14:05,793][dataloader][INFO] - Generating new data at: /content/bd3lms/data/lm1b_test_bs128_wrapped.dat
# [2026-02-15 12:14:05,793][dataloader][INFO] - streaming=True
#
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Map: 100%|██████████| 1000/1000 [00:00<00:00, 2300.39 examples/s]
# Map: 100%|██████████| 1000/1000 [00:00<00:00, 2292.77 examples/s]
#
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Map: 100%|██████████| 1000/1000 [00:00<00:00, 36043.14 examples/s]
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 1 processes
# ----------------------------------------------------------------------------------------------------
#
# 2026-02-15 12:15:50.531878: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771157750.562003   12039 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771157750.571026   12039 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771157750.593437   12039 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771157750.593480   12039 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771157750.593488   12039 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771157750.593494   12039 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-02-15 12:15:50.599654: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/connectors/data_connector.py:476: Your `val_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
# /usr/local/lib/python3.12/dist-packages/torch/distributed/distributed_c10d.py:4631: UserWarning: No device id is provided via `init_process_group` or `barrier `. Using the current device set by the user.
#   warnings.warn(  # warn only once
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val/bpd          │    10.095004081726074     │
# │          val/nll          │     6.997323989868164     │
# │          val/ppl          │    1093.7025146484375     │
# └───────────────────────────┴───────────────────────────┘

# %%
def print_table(rows):
    if not rows:
        print("No data to display.")
        return

    columns = list(rows[0].keys())

    str_rows = [
        {col: str(row.get(col, "")) for col in columns}
        for row in rows
    ]

    widths = {
        col: max(len(col), max(len(row[col]) for row in str_rows))
        for col in columns
    }

    def print_separator():
        print("+" + "+".join("-" * (widths[col] + 2) for col in columns) + "+")

    def print_row(row):
        print(
            "| " +
            " | ".join(row[col].ljust(widths[col]) for col in columns) +
            " |"
        )

    # Print table
    print_separator()
    print_row({col: col for col in columns})
    print_separator()
    for row in str_rows:
        print_row(row)
    print_separator()

print_table(results)
# Out:
# +-------------------------+-------------------+--------------------+
# | model                   | block_size_Lprime | val_ppl            |
# +-------------------------+-------------------+--------------------+
# | Block diffusion (BD3LM) | 16                | 1150.148193359375  |
# | Block diffusion (BD3LM) | 8                 | 1078.5657958984375 |
# | Block diffusion (BD3LM) | 4                 | 1093.7025146484375 |
# +-------------------------+-------------------+--------------------+
