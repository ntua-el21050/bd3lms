# %%
# !git clone https://github.com/ntua-el21050/bd3lms.git
# Out:
# Cloning into 'bd3lms'...
# remote: Enumerating objects: 825, done.
# remote: Counting objects: 100% (283/283), done.
# remote: Compressing objects: 100% (89/89), done.
# remote: Total 825 (delta 230), reused 219 (delta 194), pack-reused 542 (from 1)
# Receiving objects: 100% (825/825), 2.96 MiB | 8.65 MiB/s, done.
# Resolving deltas: 100% (522/522), done.

# %%
# %%capture
# !pip install -r bd3lms/requirements.txt

# %%
import subprocess
import re
from pathlib import Path

def run_main(overrides, timeout=None):
    """Run `python -u main.py ...` and return combined stdout/stderr text."""
    env = dict(os.environ)
    env.setdefault("HYDRA_FULL_ERROR", "1")
    cmd = [sys.executable, "-u", "bd3lms/main.py", *overrides]
    print("\n$", " ".join(cmd))
    proc = subprocess.run(
        cmd,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True,
        timeout=timeout,
        check=False,
        env=env,
    )
    print(proc.stdout[-4000:])  # tail for quick visibility
    if proc.returncode != 0:
        raise RuntimeError(f"Command failed with return code {proc.returncode}")
    return proc.stdout

_METRIC_PATTERNS = [
    # Key: value (some loggers print this)
    re.compile(r"val/ppl\s*[:=]\s*([0-9]+(?:\.[0-9]+)?(?:e[+-]?\d+)?)", re.IGNORECASE),
    re.compile(r"'val/ppl'\s*:\s*([0-9]+(?:\.[0-9]+)?(?:e[+-]?\d+)?)", re.IGNORECASE),

    # Lightning "rich" table row (note the unicode box character │)
    re.compile(r"val/ppl\s*[│|]\s*([0-9]+(?:\.[0-9]+)?(?:e[+-]?\d+)?)", re.IGNORECASE),
]

def extract_val_ppl(log_text: str):
    # First try line-based parse from the end (most reliable for tables)
    for line in reversed(log_text.splitlines()):
        if "val/ppl" in line.lower():
            m = re.search(r"val/ppl.*?([0-9]+(?:\.[0-9]+)?(?:e[+-]?\d+)?)", line, re.IGNORECASE)
            if m:
                return float(m.group(1))

    # Fallback: scan entire text with known patterns
    hits = []
    for pat in _METRIC_PATTERNS:
        hits.extend(pat.findall(log_text))
    return float(hits[-1]) if hits else None

def _small_loader_overrides(batch_size=8, num_workers=2):
    """Overrides needed to avoid huge default batch sizes on Colab."""
    return [
        f"loader.global_batch_size={batch_size}",
        f"loader.eval_global_batch_size={batch_size}",
        f"loader.batch_size={batch_size}",
        f"loader.eval_batch_size={batch_size}",
        f"loader.num_workers={num_workers}",
        "trainer.accumulate_grad_batches=1",
    ]

def train_run(run_name, algo, block_size=None, from_pretrained=None, max_steps=800, extra_overrides=None):
    """Train a model (optionally from a base checkpoint) and return the last.ckpt path."""
    save_dir = Path("/content/repro_runs") / run_name
    if save_dir.exists():
        shutil.rmtree(save_dir)
    save_dir.mkdir(parents=True, exist_ok=True)

    overrides = [
        "mode=eval",
        "data=lm1b-wrap",
        "data.cache_dir=/content/bd3lms/data",
        "data.streaming=true",
        "data.max_train_samples=5000",
        # For LM1B, validation uses the 'test' split in this codebase
        "model=tiny",
        "model.length=128",
        "model.attn_backend=sdpa",
        f"algo={algo}",
        "trainer.accelerator=gpu",
        "trainer.devices=1",
        "trainer.num_nodes=1",
        "trainer.precision=16-mixed",
        "trainer.num_sanity_val_steps=0",
        "trainer.log_every_n_steps=10",
        "trainer.val_check_interval=50",
        f"trainer.max_steps={max_steps}",
        "data.max_valid_samples=1000",
        "data.max_test_samples=1000",
        f"checkpointing.save_dir=/content/repro_runs/{run_name}",
        "checkpointing.resume_from_ckpt=false",
        "wandb=null",
    ]
    overrides.extend(_small_loader_overrides(batch_size=8, num_workers=2))
    if block_size is not None:
        overrides.append(f"block_size={block_size}")
    if from_pretrained is not None:
        overrides.append(f"training.from_pretrained={from_pretrained}")
    if extra_overrides:
        overrides.extend(extra_overrides)

    _ = run_main(overrides)
    ckpt = save_dir / "checkpoints" / "last.ckpt"
    if not ckpt.exists():
        raise FileNotFoundError(f"Expected checkpoint not found: {ckpt}")
    return str(ckpt)

def eval_run(algo, checkpoint_path, block_size=None, extra_overrides=None):
    """Evaluate perplexity (val/ppl) for a given checkpoint."""
    overrides = [
        "mode=ppl_eval",
        "data=lm1b-wrap",
        "data.cache_dir=/content/bd3lms/data",
        "data.streaming=true",
        # For LM1B, `get_dataloaders` maps validation to the 'test' split
        "data.max_test_samples=1000",
        "data.max_valid_samples=1000",
        "data.max_train_samples=1000",
        "+data.skip_samples=0",
        "model=tiny",
        "model.length=128",
        "model.attn_backend=sdpa",
        f"algo={algo}",
        f"eval.checkpoint_path={checkpoint_path}",
        "trainer.accelerator=gpu",
        "trainer.devices=1",
        "trainer.num_nodes=1",
        "trainer.precision=16-mixed",
        "trainer.num_sanity_val_steps=0",
        "wandb=null",
    ]
    overrides.extend(_small_loader_overrides(batch_size=8, num_workers=2))
    if block_size is not None:
        overrides.append(f"block_size={block_size}")
    if extra_overrides:
        overrides.extend(extra_overrides)

    log_text = run_main(overrides)
    ppl = extract_val_ppl(log_text)
    if ppl is None:
        raise ValueError("Could not parse val/ppl from output. Try increasing the log tail or printing full logs.")
    return ppl

# %%
import os
import shutil
import sys

results = []

bd3lm_base_run = "bd3lm_base_len128"
bd3lm_base_ckpt = train_run(
    bd3lm_base_run,
    algo="bd3lm",
    block_size=128,
    extra_overrides=[
        "training.resample=false",
        "algo.var_min=false",
        "algo.clip_search_widths=[]",
    ],
)

for Lprime in [16, 8, 4]:
    finetune_run = f"bd3lm_finetune_Lp{Lprime}"
    finetune_ckpt = train_run(
        finetune_run,
        algo="bd3lm",
        block_size=Lprime,
        from_pretrained=bd3lm_base_ckpt,
        extra_overrides=[
            "training.resample=true",
            "algo.var_min=false",
            "algo.clip_search_widths=[]",
        ],
    )
    ppl = eval_run(
        algo="bd3lm",
        checkpoint_path=finetune_ckpt,
        block_size=Lprime,
        extra_overrides=[
            "algo.var_min=false",
        ],
    )
    results.append({"model": "Block diffusion (BD3LM)", "block_size_Lprime": Lprime, "val_ppl": ppl})
# Out:
# $ /usr/bin/python3 -u bd3lms/main.py mode=eval data=lm1b-wrap data.cache_dir=/content/bd3lms/data data.streaming=true data.max_train_samples=5000 model=tiny model.length=128 model.attn_backend=sdpa algo=bd3lm trainer.accelerator=gpu trainer.devices=1 trainer.num_nodes=1 trainer.precision=16-mixed trainer.num_sanity_val_steps=0 trainer.log_every_n_steps=10 trainer.val_check_interval=50 trainer.max_steps=800 data.max_valid_samples=1000 data.max_test_samples=1000 checkpointing.save_dir=/content/repro_runs/bd3lm_base_len128 checkpointing.resume_from_ckpt=false wandb=null loader.global_batch_size=8 loader.eval_global_batch_size=8 loader.batch_size=8 loader.eval_batch_size=8 loader.num_workers=2 trainer.accumulate_grad_batches=1 block_size=128 training.resample=false algo.var_min=false algo.clip_search_widths=[]
#  [00:38<00:08,  3.10it/s, v_num=0]
# Epoch 3:  82%|████████▏ | 120/146 [00:38<00:08,  3.10it/s, v_num=0]
# Epoch 3:  96%|█████████▌| 140/146 [00:41<00:01,  3.37it/s, v_num=0]
# Epoch 3:  96%|█████████▌| 140/146 [00:41<00:01,  3.37it/s, v_num=0]
# Epoch 3: 100%|██████████| 146/146 [00:42<00:00,  3.44it/s, v_num=0]
# Epoch 3: 100%|██████████| 146/146 [00:42<00:00,  3.44it/s, v_num=0]
# Epoch 3: 100%|██████████| 146/146 [00:42<00:00,  3.44it/s, v_num=0]
# Epoch 3:   0%|          | 0/146 [00:00<?, ?it/s, v_num=0]
# Epoch 4:   0%|          | 0/146 [00:00<?, ?it/s, v_num=0]
# Epoch 4:  14%|█▎        | 20/146 [00:02<00:18,  6.98it/s, v_num=0]
# Epoch 4:  14%|█▎        | 20/146 [00:02<00:18,  6.98it/s, v_num=0]
# Epoch 4:  27%|██▋       | 40/146 [00:05<00:14,  7.08it/s, v_num=0]
# Epoch 4:  27%|██▋       | 40/146 [00:05<00:14,  7.08it/s, v_num=0]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/29 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/29 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  69%|██████▉   | 20/29 [00:00<00:00, 21.82it/s]
#
# Validation DataLoader 0: 100%|██████████| 29/29 [00:01<00:00, 21.98it/s]
#
#
# Epoch 4:  27%|██▋       | 40/146 [00:08<00:22,  4.67it/s, v_num=0]Epoch 4, global step 634: 'val/nll' was not in top 1
#
# Epoch 4:  41%|████      | 60/146 [00:15<00:22,  3.79it/s, v_num=0]
# Epoch 4:  41%|████      | 60/146 [00:15<00:22,  3.79it/s, v_num=0]
# Epoch 4:  55%|█████▍    | 80/146 [00:18<00:15,  4.30it/s, v_num=0]
# Epoch 4:  55%|█████▍    | 80/146 [00:18<00:15,  4.30it/s, v_num=0]
# Epoch 4:  68%|██████▊   | 100/146 [00:21<00:09,  4.67it/s, v_num=0]
# Epoch 4:  68%|██████▊   | 100/146 [00:21<00:09,  4.67it/s, v_num=0]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/29 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/29 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  69%|██████▉   | 20/29 [00:00<00:00, 21.75it/s]
#
# Validation DataLoader 0: 100%|██████████| 29/29 [00:01<00:00, 21.70it/s]
#
#
# Epoch 4:  68%|██████▊   | 100/146 [00:22<00:10,  4.36it/s, v_num=0]Epoch 4, global step 684: 'val/nll' was not in top 1
#
# Epoch 4:  82%|████████▏ | 120/146 [00:27<00:06,  4.32it/s, v_num=0]
# Epoch 4:  82%|████████▏ | 120/146 [00:27<00:06,  4.32it/s, v_num=0]
# Epoch 4:  96%|█████████▌| 140/146 [00:30<00:01,  4.57it/s, v_num=0]
# Epoch 4:  96%|█████████▌| 140/146 [00:30<00:01,  4.57it/s, v_num=0]
# Epoch 4: 100%|██████████| 146/146 [00:31<00:00,  4.65it/s, v_num=0]
# Epoch 4: 100%|██████████| 146/146 [00:31<00:00,  4.65it/s, v_num=0]
# Epoch 4: 100%|██████████| 146/146 [00:31<00:00,  4.65it/s, v_num=0]
# Epoch 4:   0%|          | 0/146 [00:00<?, ?it/s, v_num=0]
# Epoch 5:   0%|          | 0/146 [00:00<?, ?it/s, v_num=0]
# Epoch 5:  14%|█▎        | 20/146 [00:02<00:17,  7.06it/s, v_num=0]
# Epoch 5:  14%|█▎        | 20/146 [00:02<00:17,  7.06it/s, v_num=0]
# Epoch 5:  27%|██▋       | 40/146 [00:05<00:15,  6.93it/s, v_num=0]
# Epoch 5:  27%|██▋       | 40/146 [00:05<00:15,  6.93it/s, v_num=0]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/29 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/29 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  69%|██████▉   | 20/29 [00:00<00:00, 21.42it/s]
#
# Validation DataLoader 0: 100%|██████████| 29/29 [00:01<00:00, 21.71it/s]
#
#
# Epoch 5:  27%|██▋       | 40/146 [00:08<00:23,  4.59it/s, v_num=0]Epoch 5, global step 780: 'val/nll' was not in top 1
#
# Epoch 5:  41%|████      | 60/146 [00:11<00:16,  5.17it/s, v_num=0]
# Epoch 5:  41%|████      | 60/146 [00:11<00:16,  5.17it/s, v_num=0]
# Epoch 5:  41%|████      | 60/146 [00:13<00:18,  4.61it/s, v_num=0]`Trainer.fit` stopped: `max_steps=800` reached.
#
# Epoch 5:  41%|████      | 60/146 [00:13<00:18,  4.61it/s, v_num=0]
#
#
# $ /usr/bin/python3 -u bd3lms/main.py mode=eval data=lm1b-wrap data.cache_dir=/content/bd3lms/data data.streaming=true data.max_train_samples=5000 model=tiny model.length=128 model.attn_backend=sdpa algo=bd3lm trainer.accelerator=gpu trainer.devices=1 trainer.num_nodes=1 trainer.precision=16-mixed trainer.num_sanity_val_steps=0 trainer.log_every_n_steps=10 trainer.val_check_interval=50 trainer.max_steps=800 data.max_valid_samples=1000 data.max_test_samples=1000 checkpointing.save_dir=/content/repro_runs/bd3lm_finetune_Lp16 checkpointing.resume_from_ckpt=false wandb=null loader.global_batch_size=8 loader.eval_global_batch_size=8 loader.batch_size=8 loader.eval_batch_size=8 loader.num_workers=2 trainer.accumulate_grad_batches=1 block_size=16 training.from_pretrained=/content/repro_runs/bd3lm_base_len128/checkpoints/last.ckpt training.resample=true algo.var_min=false algo.clip_search_widths=[]
# it/s]
#
# Validation DataLoader 0:   0%|          | 0/29 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  69%|██████▉   | 20/29 [00:00<00:00, 21.39it/s]
#
# Validation DataLoader 0: 100%|██████████| 29/29 [00:01<00:00, 21.63it/s]
#
#
# Epoch 4:  27%|██▋       | 40/146 [00:08<00:22,  4.63it/s, v_num=0]Epoch 4, global step 584: 'val/nll' was not in top 1
#
# Epoch 4:  41%|████      | 60/146 [00:12<00:18,  4.77it/s, v_num=0]
# Epoch 4:  41%|████      | 60/146 [00:12<00:18,  4.77it/s, v_num=0]
# Epoch 4:  55%|█████▍    | 80/146 [00:15<00:12,  5.19it/s, v_num=0]
# Epoch 4:  55%|█████▍    | 80/146 [00:15<00:12,  5.19it/s, v_num=0]
# Epoch 4:  68%|██████▊   | 100/146 [00:18<00:08,  5.48it/s, v_num=0]
# Epoch 4:  68%|██████▊   | 100/146 [00:18<00:08,  5.48it/s, v_num=0]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/29 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/29 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  69%|██████▉   | 20/29 [00:00<00:00, 21.81it/s]
#
# Validation DataLoader 0: 100%|██████████| 29/29 [00:01<00:00, 21.93it/s]
#
#
# Epoch 4:  68%|██████▊   | 100/146 [00:19<00:09,  5.06it/s, v_num=0]Epoch 4, global step 634: 'val/nll' was not in top 1
#
# Epoch 4:  82%|████████▏ | 120/146 [00:29<00:06,  4.13it/s, v_num=0]
# Epoch 4:  82%|████████▏ | 120/146 [00:29<00:06,  4.13it/s, v_num=0]
# Epoch 4:  96%|█████████▌| 140/146 [00:31<00:01,  4.39it/s, v_num=0]
# Epoch 4:  96%|█████████▌| 140/146 [00:31<00:01,  4.39it/s, v_num=0]
# Epoch 4: 100%|██████████| 146/146 [00:32<00:00,  4.46it/s, v_num=0]
# Epoch 4: 100%|██████████| 146/146 [00:32<00:00,  4.46it/s, v_num=0]
# Epoch 4: 100%|██████████| 146/146 [00:32<00:00,  4.46it/s, v_num=0]
# Epoch 4:   0%|          | 0/146 [00:00<?, ?it/s, v_num=0]
# Epoch 5:   0%|          | 0/146 [00:00<?, ?it/s, v_num=0]
# Epoch 5:  14%|█▎        | 20/146 [00:02<00:18,  6.83it/s, v_num=0]
# Epoch 5:  14%|█▎        | 20/146 [00:02<00:18,  6.83it/s, v_num=0]
# Epoch 5:  27%|██▋       | 40/146 [00:05<00:15,  6.89it/s, v_num=0]
# Epoch 5:  27%|██▋       | 40/146 [00:05<00:15,  6.89it/s, v_num=0]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/29 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/29 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  69%|██████▉   | 20/29 [00:00<00:00, 21.06it/s]
#
# Validation DataLoader 0: 100%|██████████| 29/29 [00:01<00:00, 21.28it/s]
#
#
# Epoch 5:  27%|██▋       | 40/146 [00:08<00:23,  4.54it/s, v_num=0]Epoch 5, global step 730: 'val/nll' was not in top 1
#
# Epoch 5:  41%|████      | 60/146 [00:11<00:16,  5.10it/s, v_num=0]
# Epoch 5:  41%|████      | 60/146 [00:11<00:16,  5.10it/s, v_num=0]
# Epoch 5:  55%|█████▍    | 80/146 [00:14<00:12,  5.42it/s, v_num=0]
# Epoch 5:  55%|█████▍    | 80/146 [00:14<00:12,  5.42it/s, v_num=0]
# Epoch 5:  68%|██████▊   | 100/146 [00:17<00:08,  5.66it/s, v_num=0]
# Epoch 5:  68%|██████▊   | 100/146 [00:17<00:08,  5.66it/s, v_num=0]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/29 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/29 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  69%|██████▉   | 20/29 [00:00<00:00, 20.68it/s]
#
# Validation DataLoader 0: 100%|██████████| 29/29 [00:01<00:00, 20.77it/s]
#
#
# Epoch 5:  68%|██████▊   | 100/146 [00:19<00:08,  5.19it/s, v_num=0]Epoch 5, global step 780: 'val/nll' was not in top 1
#
# Epoch 5:  82%|████████▏ | 120/146 [00:29<00:06,  4.12it/s, v_num=0]
# Epoch 5:  82%|████████▏ | 120/146 [00:29<00:06,  4.12it/s, v_num=0]
# Epoch 5:  82%|████████▏ | 120/146 [00:29<00:06,  4.12it/s, v_num=0]`Trainer.fit` stopped: `max_steps=800` reached.
#
# Epoch 5:  82%|████████▏ | 120/146 [00:29<00:06,  4.12it/s, v_num=0]
#
#
# $ /usr/bin/python3 -u bd3lms/main.py mode=ppl_eval data=lm1b-wrap data.cache_dir=/content/bd3lms/data data.streaming=true data.max_test_samples=1000 data.max_valid_samples=1000 data.max_train_samples=1000 +data.skip_samples=0 model=tiny model.length=128 model.attn_backend=sdpa algo=bd3lm eval.checkpoint_path=/content/repro_runs/bd3lm_finetune_Lp16/checkpoints/last.ckpt trainer.accelerator=gpu trainer.devices=1 trainer.num_nodes=1 trainer.precision=16-mixed trainer.num_sanity_val_steps=0 wandb=null loader.global_batch_size=8 loader.eval_global_batch_size=8 loader.batch_size=8 loader.eval_batch_size=8 loader.num_workers=2 trainer.accumulate_grad_batches=1 block_size=16 algo.var_min=false
# er(limit_train_batches=1.0)` was configured so 100% of the batches per epoch will be used..
# `Trainer(limit_val_batches=1.0)` was configured so 100% of the batches will be used..
# Seed set to 1
# [2026-01-25 00:30:26,076][dataloader][INFO] - Generating new data at: /content/bd3lms/data/lm1b_test_bs128_wrapped.dat
# [2026-01-25 00:30:26,076][dataloader][INFO] - streaming=True
#
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Map: 100%|██████████| 1000/1000 [00:00<00:00, 2312.42 examples/s]
# Map: 100%|██████████| 1000/1000 [00:00<00:00, 2305.43 examples/s]
#
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Map: 100%|██████████| 1000/1000 [00:00<00:00, 40392.38 examples/s]
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 1 processes
# ----------------------------------------------------------------------------------------------------
#
# 2026-01-25 00:31:52.949905: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769301112.967388   20360 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769301112.972444   20360 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769301112.986102   20360 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769301112.986122   20360 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769301112.986125   20360 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769301112.986127   20360 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-25 00:31:52.990107: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/connectors/data_connector.py:476: Your `val_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
# /usr/local/lib/python3.12/dist-packages/torch/distributed/distributed_c10d.py:4631: UserWarning: No device id is provided via `init_process_group` or `barrier `. Using the current device set by the user.
#   warnings.warn(  # warn only once
#
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/29 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/29 [00:00<?, ?it/s]
# Validation DataLoader 0:  69%|██████▉   | 20/29 [00:01<00:00, 13.27it/s]
# Validation DataLoader 0: 100%|██████████| 29/29 [00:01<00:00, 15.15it/s]
# Validation DataLoader 0: 100%|██████████| 29/29 [00:01<00:00, 14.88it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val/bpd          │    10.167603492736816     │
# │          val/nll          │    7.0476460456848145     │
# │          val/ppl          │     1150.148193359375     │
# └───────────────────────────┴───────────────────────────┘
#
#
# $ /usr/bin/python3 -u bd3lms/main.py mode=eval data=lm1b-wrap data.cache_dir=/content/bd3lms/data data.streaming=true data.max_train_samples=5000 model=tiny model.length=128 model.attn_backend=sdpa algo=bd3lm trainer.accelerator=gpu trainer.devices=1 trainer.num_nodes=1 trainer.precision=16-mixed trainer.num_sanity_val_steps=0 trainer.log_every_n_steps=10 trainer.val_check_interval=50 trainer.max_steps=800 data.max_valid_samples=1000 data.max_test_samples=1000 checkpointing.save_dir=/content/repro_runs/bd3lm_finetune_Lp8 checkpointing.resume_from_ckpt=false wandb=null loader.global_batch_size=8 loader.eval_global_batch_size=8 loader.batch_size=8 loader.eval_batch_size=8 loader.num_workers=2 trainer.accumulate_grad_batches=1 block_size=8 training.from_pretrained=/content/repro_runs/bd3lm_base_len128/checkpoints/last.ckpt training.resample=true algo.var_min=false algo.clip_search_widths=[]
# it/s]
#
# Validation DataLoader 0:   0%|          | 0/29 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  69%|██████▉   | 20/29 [00:00<00:00, 21.07it/s]
#
# Validation DataLoader 0: 100%|██████████| 29/29 [00:01<00:00, 21.27it/s]
#
#
# Epoch 4:  27%|██▋       | 40/146 [00:08<00:23,  4.47it/s, v_num=0]Epoch 4, global step 584: 'val/nll' was not in top 1
#
# Epoch 4:  41%|████      | 60/146 [00:14<00:20,  4.21it/s, v_num=0]
# Epoch 4:  41%|████      | 60/146 [00:14<00:20,  4.21it/s, v_num=0]
# Epoch 4:  55%|█████▍    | 80/146 [00:17<00:14,  4.64it/s, v_num=0]
# Epoch 4:  55%|█████▍    | 80/146 [00:17<00:14,  4.64it/s, v_num=0]
# Epoch 4:  68%|██████▊   | 100/146 [00:20<00:09,  4.94it/s, v_num=0]
# Epoch 4:  68%|██████▊   | 100/146 [00:20<00:09,  4.94it/s, v_num=0]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/29 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/29 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  69%|██████▉   | 20/29 [00:00<00:00, 20.61it/s]
#
# Validation DataLoader 0: 100%|██████████| 29/29 [00:01<00:00, 20.84it/s]
#
#
# Epoch 4:  68%|██████▊   | 100/146 [00:21<00:10,  4.58it/s, v_num=0]Epoch 4, global step 634: 'val/nll' was not in top 1
#
# Epoch 4:  82%|████████▏ | 120/146 [00:32<00:07,  3.69it/s, v_num=0]
# Epoch 4:  82%|████████▏ | 120/146 [00:32<00:07,  3.69it/s, v_num=0]
# Epoch 4:  96%|█████████▌| 140/146 [00:35<00:01,  3.95it/s, v_num=0]
# Epoch 4:  96%|█████████▌| 140/146 [00:35<00:01,  3.95it/s, v_num=0]
# Epoch 4: 100%|██████████| 146/146 [00:36<00:00,  4.02it/s, v_num=0]
# Epoch 4: 100%|██████████| 146/146 [00:36<00:00,  4.02it/s, v_num=0]
# Epoch 4: 100%|██████████| 146/146 [00:36<00:00,  4.02it/s, v_num=0]
# Epoch 4:   0%|          | 0/146 [00:00<?, ?it/s, v_num=0]
# Epoch 5:   0%|          | 0/146 [00:00<?, ?it/s, v_num=0]
# Epoch 5:  14%|█▎        | 20/146 [00:02<00:18,  6.84it/s, v_num=0]
# Epoch 5:  14%|█▎        | 20/146 [00:02<00:18,  6.84it/s, v_num=0]
# Epoch 5:  27%|██▋       | 40/146 [00:05<00:15,  6.72it/s, v_num=0]
# Epoch 5:  27%|██▋       | 40/146 [00:05<00:15,  6.72it/s, v_num=0]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/29 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/29 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  69%|██████▉   | 20/29 [00:00<00:00, 20.82it/s]
#
# Validation DataLoader 0: 100%|██████████| 29/29 [00:01<00:00, 20.96it/s]
#
#
# Epoch 5:  27%|██▋       | 40/146 [00:09<00:23,  4.43it/s, v_num=0]Epoch 5, global step 730: 'val/nll' was not in top 1
#
# Epoch 5:  41%|████      | 60/146 [00:17<00:25,  3.40it/s, v_num=0]
# Epoch 5:  41%|████      | 60/146 [00:17<00:25,  3.40it/s, v_num=0]
# Epoch 5:  55%|█████▍    | 80/146 [00:20<00:17,  3.88it/s, v_num=0]
# Epoch 5:  55%|█████▍    | 80/146 [00:20<00:17,  3.88it/s, v_num=0]
# Epoch 5:  68%|██████▊   | 100/146 [00:23<00:10,  4.25it/s, v_num=0]
# Epoch 5:  68%|██████▊   | 100/146 [00:23<00:10,  4.25it/s, v_num=0]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/29 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/29 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  69%|██████▉   | 20/29 [00:00<00:00, 21.19it/s]
#
# Validation DataLoader 0: 100%|██████████| 29/29 [00:01<00:00, 21.37it/s]
#
#
# Epoch 5:  68%|██████▊   | 100/146 [00:25<00:11,  3.98it/s, v_num=0]Epoch 5, global step 780: 'val/nll' was not in top 1
#
# Epoch 5:  82%|████████▏ | 120/146 [00:29<00:06,  4.05it/s, v_num=0]
# Epoch 5:  82%|████████▏ | 120/146 [00:29<00:06,  4.05it/s, v_num=0]
# Epoch 5:  82%|████████▏ | 120/146 [00:29<00:06,  4.05it/s, v_num=0]`Trainer.fit` stopped: `max_steps=800` reached.
#
# Epoch 5:  82%|████████▏ | 120/146 [00:29<00:06,  4.05it/s, v_num=0]
#
#
# $ /usr/bin/python3 -u bd3lms/main.py mode=ppl_eval data=lm1b-wrap data.cache_dir=/content/bd3lms/data data.streaming=true data.max_test_samples=1000 data.max_valid_samples=1000 data.max_train_samples=1000 +data.skip_samples=0 model=tiny model.length=128 model.attn_backend=sdpa algo=bd3lm eval.checkpoint_path=/content/repro_runs/bd3lm_finetune_Lp8/checkpoints/last.ckpt trainer.accelerator=gpu trainer.devices=1 trainer.num_nodes=1 trainer.precision=16-mixed trainer.num_sanity_val_steps=0 wandb=null loader.global_batch_size=8 loader.eval_global_batch_size=8 loader.batch_size=8 loader.eval_batch_size=8 loader.num_workers=2 trainer.accumulate_grad_batches=1 block_size=8 algo.var_min=false
# er(limit_train_batches=1.0)` was configured so 100% of the batches per epoch will be used..
# `Trainer(limit_val_batches=1.0)` was configured so 100% of the batches will be used..
# Seed set to 1
# [2026-01-25 00:37:34,660][dataloader][INFO] - Generating new data at: /content/bd3lms/data/lm1b_test_bs128_wrapped.dat
# [2026-01-25 00:37:34,660][dataloader][INFO] - streaming=True
#
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Map: 100%|██████████| 1000/1000 [00:00<00:00, 2313.43 examples/s]
# Map: 100%|██████████| 1000/1000 [00:00<00:00, 2306.41 examples/s]
#
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Map: 100%|██████████| 1000/1000 [00:00<00:00, 37748.09 examples/s]
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 1 processes
# ----------------------------------------------------------------------------------------------------
#
# 2026-01-25 00:39:42.584917: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769301582.602630   22365 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769301582.607679   22365 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769301582.620880   22365 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769301582.620900   22365 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769301582.620903   22365 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769301582.620905   22365 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-25 00:39:42.624831: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/connectors/data_connector.py:476: Your `val_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
# /usr/local/lib/python3.12/dist-packages/torch/distributed/distributed_c10d.py:4631: UserWarning: No device id is provided via `init_process_group` or `barrier `. Using the current device set by the user.
#   warnings.warn(  # warn only once
#
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/29 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/29 [00:00<?, ?it/s]
# Validation DataLoader 0:  69%|██████▉   | 20/29 [00:01<00:00, 13.69it/s]
# Validation DataLoader 0: 100%|██████████| 29/29 [00:01<00:00, 15.53it/s]
# Validation DataLoader 0: 100%|██████████| 29/29 [00:01<00:00, 15.29it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val/bpd          │    10.074898719787598     │
# │          val/nll          │     6.983387470245361     │
# │          val/ppl          │    1078.5657958984375     │
# └───────────────────────────┴───────────────────────────┘
#
#
# $ /usr/bin/python3 -u bd3lms/main.py mode=eval data=lm1b-wrap data.cache_dir=/content/bd3lms/data data.streaming=true data.max_train_samples=5000 model=tiny model.length=128 model.attn_backend=sdpa algo=bd3lm trainer.accelerator=gpu trainer.devices=1 trainer.num_nodes=1 trainer.precision=16-mixed trainer.num_sanity_val_steps=0 trainer.log_every_n_steps=10 trainer.val_check_interval=50 trainer.max_steps=800 data.max_valid_samples=1000 data.max_test_samples=1000 checkpointing.save_dir=/content/repro_runs/bd3lm_finetune_Lp4 checkpointing.resume_from_ckpt=false wandb=null loader.global_batch_size=8 loader.eval_global_batch_size=8 loader.batch_size=8 loader.eval_batch_size=8 loader.num_workers=2 trainer.accumulate_grad_batches=1 block_size=4 training.from_pretrained=/content/repro_runs/bd3lm_base_len128/checkpoints/last.ckpt training.resample=true algo.var_min=false algo.clip_search_widths=[]
# it/s]
#
# Validation DataLoader 0:   0%|          | 0/29 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  69%|██████▉   | 20/29 [00:00<00:00, 20.81it/s]
#
# Validation DataLoader 0: 100%|██████████| 29/29 [00:01<00:00, 21.00it/s]
#
#
# Epoch 4:  27%|██▋       | 40/146 [00:08<00:23,  4.54it/s, v_num=0]Epoch 4, global step 584: 'val/nll' was not in top 1
#
# Epoch 4:  41%|████      | 60/146 [00:12<00:17,  4.95it/s, v_num=0]
# Epoch 4:  41%|████      | 60/146 [00:12<00:17,  4.94it/s, v_num=0]
# Epoch 4:  55%|█████▍    | 80/146 [00:15<00:12,  5.31it/s, v_num=0]
# Epoch 4:  55%|█████▍    | 80/146 [00:15<00:12,  5.31it/s, v_num=0]
# Epoch 4:  68%|██████▊   | 100/146 [00:17<00:08,  5.56it/s, v_num=0]
# Epoch 4:  68%|██████▊   | 100/146 [00:17<00:08,  5.56it/s, v_num=0]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/29 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/29 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  69%|██████▉   | 20/29 [00:00<00:00, 20.80it/s]
#
# Validation DataLoader 0: 100%|██████████| 29/29 [00:01<00:00, 20.95it/s]
#
#
# Epoch 4:  68%|██████▊   | 100/146 [00:19<00:09,  5.11it/s, v_num=0]Epoch 4, global step 634: 'val/nll' was not in top 1
#
# Epoch 4:  82%|████████▏ | 120/146 [00:24<00:05,  4.95it/s, v_num=0]
# Epoch 4:  82%|████████▏ | 120/146 [00:24<00:05,  4.95it/s, v_num=0]
# Epoch 4:  96%|█████████▌| 140/146 [00:27<00:01,  5.16it/s, v_num=0]
# Epoch 4:  96%|█████████▌| 140/146 [00:27<00:01,  5.16it/s, v_num=0]
# Epoch 4: 100%|██████████| 146/146 [00:27<00:00,  5.22it/s, v_num=0]
# Epoch 4: 100%|██████████| 146/146 [00:27<00:00,  5.22it/s, v_num=0]
# Epoch 4: 100%|██████████| 146/146 [00:27<00:00,  5.22it/s, v_num=0]
# Epoch 4:   0%|          | 0/146 [00:00<?, ?it/s, v_num=0]
# Epoch 5:   0%|          | 0/146 [00:00<?, ?it/s, v_num=0]
# Epoch 5:  14%|█▎        | 20/146 [00:02<00:18,  6.86it/s, v_num=0]
# Epoch 5:  14%|█▎        | 20/146 [00:02<00:18,  6.86it/s, v_num=0]
# Epoch 5:  27%|██▋       | 40/146 [00:05<00:15,  6.87it/s, v_num=0]
# Epoch 5:  27%|██▋       | 40/146 [00:05<00:15,  6.87it/s, v_num=0]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/29 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/29 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  69%|██████▉   | 20/29 [00:00<00:00, 20.10it/s]
#
# Validation DataLoader 0: 100%|██████████| 29/29 [00:01<00:00, 20.52it/s]
#
#
# Epoch 5:  27%|██▋       | 40/146 [00:09<00:23,  4.42it/s, v_num=0]Epoch 5, global step 730: 'val/nll' was not in top 1
#
# Epoch 5:  41%|████      | 60/146 [00:12<00:17,  4.94it/s, v_num=0]
# Epoch 5:  41%|████      | 60/146 [00:12<00:17,  4.94it/s, v_num=0]
# Epoch 5:  55%|█████▍    | 80/146 [00:15<00:12,  5.33it/s, v_num=0]
# Epoch 5:  55%|█████▍    | 80/146 [00:15<00:12,  5.33it/s, v_num=0]
# Epoch 5:  68%|██████▊   | 100/146 [00:17<00:08,  5.59it/s, v_num=0]
# Epoch 5:  68%|██████▊   | 100/146 [00:17<00:08,  5.59it/s, v_num=0]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/29 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/29 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  69%|██████▉   | 20/29 [00:00<00:00, 20.27it/s]
#
# Validation DataLoader 0: 100%|██████████| 29/29 [00:01<00:00, 20.36it/s]
#
#
# Epoch 5:  68%|██████▊   | 100/146 [00:19<00:09,  5.10it/s, v_num=0]Epoch 5, global step 780: 'val/nll' was not in top 1
#
# Epoch 5:  82%|████████▏ | 120/146 [00:28<00:06,  4.22it/s, v_num=0]
# Epoch 5:  82%|████████▏ | 120/146 [00:28<00:06,  4.22it/s, v_num=0]
# Epoch 5:  82%|████████▏ | 120/146 [00:28<00:06,  4.22it/s, v_num=0]`Trainer.fit` stopped: `max_steps=800` reached.
#
# Epoch 5:  82%|████████▏ | 120/146 [00:28<00:06,  4.22it/s, v_num=0]
#
#
# $ /usr/bin/python3 -u bd3lms/main.py mode=ppl_eval data=lm1b-wrap data.cache_dir=/content/bd3lms/data data.streaming=true data.max_test_samples=1000 data.max_valid_samples=1000 data.max_train_samples=1000 +data.skip_samples=0 model=tiny model.length=128 model.attn_backend=sdpa algo=bd3lm eval.checkpoint_path=/content/repro_runs/bd3lm_finetune_Lp4/checkpoints/last.ckpt trainer.accelerator=gpu trainer.devices=1 trainer.num_nodes=1 trainer.precision=16-mixed trainer.num_sanity_val_steps=0 wandb=null loader.global_batch_size=8 loader.eval_global_batch_size=8 loader.batch_size=8 loader.eval_batch_size=8 loader.num_workers=2 trainer.accumulate_grad_batches=1 block_size=4 algo.var_min=false
# er(limit_train_batches=1.0)` was configured so 100% of the batches per epoch will be used..
# `Trainer(limit_val_batches=1.0)` was configured so 100% of the batches will be used..
# Seed set to 1
# [2026-01-25 00:45:19,313][dataloader][INFO] - Generating new data at: /content/bd3lms/data/lm1b_test_bs128_wrapped.dat
# [2026-01-25 00:45:19,313][dataloader][INFO] - streaming=True
#
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Map: 100%|██████████| 1000/1000 [00:00<00:00, 1293.17 examples/s]
# Map: 100%|██████████| 1000/1000 [00:00<00:00, 1290.26 examples/s]
#
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Map: 100%|██████████| 1000/1000 [00:00<00:00, 23652.13 examples/s]
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 1 processes
# ----------------------------------------------------------------------------------------------------
#
# 2026-01-25 00:47:32.876608: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769302052.906006   24515 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769302052.914856   24515 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769302052.929142   24515 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769302052.929163   24515 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769302052.929166   24515 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769302052.929168   24515 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-25 00:47:32.933326: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/connectors/data_connector.py:476: Your `val_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
# /usr/local/lib/python3.12/dist-packages/torch/distributed/distributed_c10d.py:4631: UserWarning: No device id is provided via `init_process_group` or `barrier `. Using the current device set by the user.
#   warnings.warn(  # warn only once
#
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/29 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/29 [00:00<?, ?it/s]
# Validation DataLoader 0:  69%|██████▉   | 20/29 [00:01<00:00, 12.22it/s]
# Validation DataLoader 0: 100%|██████████| 29/29 [00:02<00:00, 14.16it/s]
# Validation DataLoader 0: 100%|██████████| 29/29 [00:02<00:00, 13.96it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val/bpd          │    10.095004081726074     │
# │          val/nll          │     6.997323989868164     │
# │          val/ppl          │    1093.7025146484375     │
# └───────────────────────────┴───────────────────────────┘

# %%
def print_table(rows):
    if not rows:
        print("No data to display.")
        return

    columns = list(rows[0].keys())

    str_rows = [
        {col: str(row.get(col, "")) for col in columns}
        for row in rows
    ]

    widths = {
        col: max(len(col), max(len(row[col]) for row in str_rows))
        for col in columns
    }

    def print_separator():
        print("+" + "+".join("-" * (widths[col] + 2) for col in columns) + "+")

    def print_row(row):
        print(
            "| " +
            " | ".join(row[col].ljust(widths[col]) for col in columns) +
            " |"
        )

    # Print table
    print_separator()
    print_row({col: col for col in columns})
    print_separator()
    for row in str_rows:
        print_row(row)
    print_separator()

print_table(results)
# Out:
# +-------------------------+-------------------+--------------------+
# | model                   | block_size_Lprime | val_ppl            |
# +-------------------------+-------------------+--------------------+
# | Block diffusion (BD3LM) | 16                | 1150.148193359375  |
# | Block diffusion (BD3LM) | 8                 | 1078.5657958984375 |
# | Block diffusion (BD3LM) | 4                 | 1093.7025146484375 |
# +-------------------------+-------------------+--------------------+
