# %%
# !git clone https://github.com/kuleshov-group/bd3lms
# Out:
# Cloning into 'bd3lms'...
# remote: Enumerating objects: 544, done.
# remote: Counting objects: 100% (144/144), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 544 (delta 121), reused 108 (delta 108), pack-reused 400 (from 1)
# Receiving objects: 100% (544/544), 1.08 MiB | 19.04 MiB/s, done.
# Resolving deltas: 100% (345/345), done.

# %%
# %%capture
# !pip install -r bd3lms/requirements.txt

# %%
# !bd3lms/scripts/gen_ppl/genppl_bd3lm.sh 1024 42 4
# Out:
# Seed set to 42
# CONFIG
# ├── mode
# │   └── sample_eval
# ├── diffusion
# │   └── absorbing_state
# ├── seed
# │   └── 42
# ├── block_size
# │   └── 4
# ├── loader
# │   └── global_batch_size: 512
# │       eval_global_batch_size: 512
# │       batch_size: 512
# │       eval_batch_size: 1
# │       num_workers: 2
# │       pin_memory: true
# │
# ├── sampling
# │   └── noise_removal: false
# │       num_sample_batches: 25
# │       var_length: false
# │       logdir: /content/sample_logs/samples_bd3lm_len1024_blocksize4
# │       nucleus_p: 0.9
# │       first_hitting: true
# │       kv_cache: true
# │
# ├── training
# │   └── ema: 0.9999
# │       antithetic_sampling: true
# │       sampling_eps: 0.001
# │       coeff_clip: -1.0
# │       resample: false
# │       sampling_eps_min: 0.001
# │       sampling_eps_max: 1.0
# │       from_pretrained: null
# │       eval_nll: true
# │
# ├── eval
# │   └── checkpoint_path: kuleshov-group/bd3lm-owt-block_size4
# │       disable_ema: false
# ...

# %%
# !bd3lms/scripts/gen_ppl/genppl_bd3lm.sh 2048 42 4
# Out:
# Seed set to 42
# CONFIG
# ├── mode
# │   └── sample_eval
# ├── diffusion
# │   └── absorbing_state
# ├── seed
# │   └── 42
# ├── block_size
# │   └── 4
# ├── loader
# │   └── global_batch_size: 512
# │       eval_global_batch_size: 512
# │       batch_size: 512
# │       eval_batch_size: 1
# │       num_workers: 2
# │       pin_memory: true
# │
# ├── sampling
# │   └── noise_removal: false
# │       num_sample_batches: 25
# │       var_length: false
# │       logdir: /content/sample_logs/samples_bd3lm_len2048_blocksize4
# │       nucleus_p: 0.9
# │       first_hitting: true
# │       kv_cache: true
# │
# ├── training
# │   └── ema: 0.9999
# │       antithetic_sampling: true
# │       sampling_eps: 0.001
# │       coeff_clip: -1.0
# │       resample: false
# │       sampling_eps_min: 0.001
# │       sampling_eps_max: 1.0
# │       from_pretrained: null
# │       eval_nll: true
# │
# ├── eval
# │   └── checkpoint_path: kuleshov-group/bd3lm-owt-block_size4
# │       disable_ema: false
# ...

# %%
# !bd3lms/scripts/gen_ppl/genppl_bd3lm.sh 1024 42 8
# Out:
# Seed set to 42
# CONFIG
# ├── mode
# │   └── sample_eval
# ├── diffusion
# │   └── absorbing_state
# ├── seed
# │   └── 42
# ├── block_size
# │   └── 8
# ├── loader
# │   └── global_batch_size: 512
# │       eval_global_batch_size: 512
# │       batch_size: 512
# │       eval_batch_size: 1
# │       num_workers: 2
# │       pin_memory: true
# │
# ├── sampling
# │   └── noise_removal: false
# │       num_sample_batches: 25
# │       var_length: false
# │       logdir: /content/sample_logs/samples_bd3lm_len1024_blocksize8
# │       nucleus_p: 0.9
# │       first_hitting: true
# │       kv_cache: true
# │
# ├── training
# │   └── ema: 0.9999
# │       antithetic_sampling: true
# │       sampling_eps: 0.001
# │       coeff_clip: -1.0
# │       resample: false
# │       sampling_eps_min: 0.001
# │       sampling_eps_max: 1.0
# │       from_pretrained: null
# │       eval_nll: true
# │
# ├── eval
# │   └── checkpoint_path: kuleshov-group/bd3lm-owt-block_size8
# │       disable_ema: false
# ...

# %%
# !bd3lms/scripts/gen_ppl/genppl_bd3lm.sh 2048 42 8
# Out:
# Seed set to 42
# CONFIG
# ├── mode
# │   └── sample_eval
# ├── diffusion
# │   └── absorbing_state
# ├── seed
# │   └── 42
# ├── block_size
# │   └── 8
# ├── loader
# │   └── global_batch_size: 512
# │       eval_global_batch_size: 512
# │       batch_size: 512
# │       eval_batch_size: 1
# │       num_workers: 2
# │       pin_memory: true
# │
# ├── sampling
# │   └── noise_removal: false
# │       num_sample_batches: 25
# │       var_length: false
# │       logdir: /content/sample_logs/samples_bd3lm_len2048_blocksize8
# │       nucleus_p: 0.9
# │       first_hitting: true
# │       kv_cache: true
# │
# ├── training
# │   └── ema: 0.9999
# │       antithetic_sampling: true
# │       sampling_eps: 0.001
# │       coeff_clip: -1.0
# │       resample: false
# │       sampling_eps_min: 0.001
# │       sampling_eps_max: 1.0
# │       from_pretrained: null
# │       eval_nll: true
# │
# ├── eval
# │   └── checkpoint_path: kuleshov-group/bd3lm-owt-block_size8
# │       disable_ema: false
# ...

# %%
# !bd3lms/scripts/gen_ppl/genppl_bd3lm.sh 1024 42 16
# Out:
# Seed set to 42
# CONFIG
# ├── mode
# │   └── sample_eval
# ├── diffusion
# │   └── absorbing_state
# ├── seed
# │   └── 42
# ├── block_size
# │   └── 16
# ├── loader
# │   └── global_batch_size: 512
# │       eval_global_batch_size: 512
# │       batch_size: 512
# │       eval_batch_size: 1
# │       num_workers: 2
# │       pin_memory: true
# │
# ├── sampling
# │   └── noise_removal: false
# │       num_sample_batches: 25
# │       var_length: false
# │       logdir: /content/sample_logs/samples_bd3lm_len1024_blocksize16
# │       nucleus_p: 0.9
# │       first_hitting: true
# │       kv_cache: true
# │
# ├── training
# │   └── ema: 0.9999
# │       antithetic_sampling: true
# │       sampling_eps: 0.001
# │       coeff_clip: -1.0
# │       resample: false
# │       sampling_eps_min: 0.001
# │       sampling_eps_max: 1.0
# │       from_pretrained: null
# │       eval_nll: true
# │
# ├── eval
# │   └── checkpoint_path: kuleshov-group/bd3lm-owt-block_size16
# ...

# %%
# !bd3lms/scripts/gen_ppl/genppl_bd3lm.sh 2048 42 16
# Out:
# Seed set to 42
# CONFIG
# ├── mode
# │   └── sample_eval
# ├── diffusion
# │   └── absorbing_state
# ├── seed
# │   └── 42
# ├── block_size
# │   └── 16
# ├── loader
# │   └── global_batch_size: 512
# │       eval_global_batch_size: 512
# │       batch_size: 512
# │       eval_batch_size: 1
# │       num_workers: 2
# │       pin_memory: true
# │
# ├── sampling
# │   └── noise_removal: false
# │       num_sample_batches: 25
# │       var_length: false
# │       logdir: /content/sample_logs/samples_bd3lm_len2048_blocksize16
# │       nucleus_p: 0.9
# │       first_hitting: true
# │       kv_cache: true
# │
# ├── training
# │   └── ema: 0.9999
# │       antithetic_sampling: true
# │       sampling_eps: 0.001
# │       coeff_clip: -1.0
# │       resample: false
# │       sampling_eps_min: 0.001
# │       sampling_eps_max: 1.0
# │       from_pretrained: null
# │       eval_nll: true
# │
# ├── eval
# │   └── checkpoint_path: kuleshov-group/bd3lm-owt-block_size16
# ...
