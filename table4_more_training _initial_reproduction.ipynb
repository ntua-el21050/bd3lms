# %%
# Clone repo
# !cd /content && rm -rf bd3lms
# !cd /content && git clone https://github.com/ntua-el21050/bd3lms.git

# Create directories
# !mkdir -p /content/bd3lms/data
# !mkdir -p /content/repro_runs
# Out:
# Cloning into 'bd3lms'...
# remote: Enumerating objects: 768, done.
# remote: Counting objects: 100% (227/227), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 768 (delta 203), reused 176 (delta 176), pack-reused 541 (from 1)
# Receiving objects: 100% (768/768), 1.78 MiB | 12.64 MiB/s, done.
# Resolving deltas: 100% (495/495), done.

# %%
# !pip install -q torchmetrics==1.6.2 datasets==3.3.2 einops==0.8.1 \
    hydra-core==1.3.2 lightning==2.5.0.post0 transformers==4.49.0
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 931.6/931.6 kB 20.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.4/485.4 kB 47.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 17.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.2/815.2 kB 68.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 131.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 21.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 79.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.5/849.5 kB 69.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.12.0 which is incompatible.

# %%
import subprocess
import re
import os
import shutil
import sys
from pathlib import Path

def run_main(overrides, timeout=None):
    """Run `python -u main.py ...` and return combined stdout/stderr text."""
    env = dict(os.environ)
    env.setdefault("HYDRA_FULL_ERROR", "1")
    cmd = [sys.executable, "-u", "bd3lms/main.py", *overrides]
    print("\n$", " ".join(cmd))
    proc = subprocess.run(
        cmd,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True,
        timeout=timeout,
        check=False,
        env=env,
    )
    print(proc.stdout[-4000:])
    if proc.returncode != 0:
        raise RuntimeError(f"Command failed with return code {proc.returncode}")
    return proc.stdout

_METRIC_PATTERNS = [
    re.compile(r"val/ppl\s*[:=]\s*([0-9]+(?:\.[0-9]+)?(?:e[+-]?\d+)?)", re.IGNORECASE),
    re.compile(r"'val/ppl'\s*:\s*([0-9]+(?:\.[0-9]+)?(?:e[+-]?\d+)?)", re.IGNORECASE),
    re.compile(r"val/ppl\s*[│|]\s*([0-9]+(?:\.[0-9]+)?(?:e[+-]?\d+)?)", re.IGNORECASE),
]

def extract_val_ppl(log_text: str):
    for line in reversed(log_text.splitlines()):
        if "val/ppl" in line.lower():
            m = re.search(r"val/ppl.*?([0-9]+(?:\.[0-9]+)?(?:e[+-]?\d+)?)", line, re.IGNORECASE)
            if m:
                return float(m.group(1))
    hits = []
    for pat in _METRIC_PATTERNS:
        hits.extend(pat.findall(log_text))
    return float(hits[-1]) if hits else None

def _small_loader_overrides(batch_size=4, num_workers=2):
    """Smaller batch size for OWT (1024 context length)."""
    return [
        f"loader.global_batch_size={batch_size}",
        f"loader.eval_global_batch_size={batch_size}",
        f"loader.batch_size={batch_size}",
        f"loader.eval_batch_size={batch_size}",
        f"loader.num_workers={num_workers}",
        "trainer.accumulate_grad_batches=1",
    ]

def train_run(run_name, algo, block_size=None, from_pretrained=None, max_steps=3000, extra_overrides=None):
    """Train a model for Table 4 (OpenWebText)."""
    save_dir = Path("/content/repro_runs") / run_name
    if save_dir.exists():
        shutil.rmtree(save_dir)
    save_dir.mkdir(parents=True, exist_ok=True)

    overrides = [
        "mode=train",

        # TABLE 4 SPECIFIC: OpenWebText, length=1024

        "data=openwebtext-split",           # ← OWT dataset
        "data.cache_dir=/content/bd3lms/data",
        "data.streaming=true",
        "data.max_train_samples=2000",      # Scaled down
        "model=tiny",
        "model.length=1024",                # ← 1024 context (8x larger than Table 3)
        "model.attn_backend=sdpa",
        f"algo={algo}",

        # Trainer settings

        "trainer.accelerator=gpu",
        "trainer.devices=1",
        "trainer.num_nodes=1",
        "trainer.precision=16-mixed",# Mixed precision για ταχύτητα
        "trainer.num_sanity_val_steps=0",
        "trainer.log_every_n_steps=10",
        "trainer.val_check_interval=10",    # ← Μικρό για λίγα samples
        f"trainer.max_steps={max_steps}",
        "data.max_valid_samples=100",
        "data.max_test_samples=100",
        f"checkpointing.save_dir=/content/repro_runs/{run_name}",
        "checkpointing.resume_from_ckpt=false",
        "wandb=null",
    ]
    overrides.extend(_small_loader_overrides(batch_size=4, num_workers=2))  # ← batch=4 για memory

    if block_size is not None:
        overrides.append(f"block_size={block_size}")
    if from_pretrained is not None:
        overrides.append(f"training.from_pretrained={from_pretrained}")
    if extra_overrides:
        overrides.extend(extra_overrides)

    _ = run_main(overrides)
    ckpt = save_dir / "checkpoints" / "last.ckpt"
    if not ckpt.exists():
        raise FileNotFoundError(f"Expected checkpoint not found: {ckpt}")
    return str(ckpt)

def eval_run(algo, checkpoint_path, block_size=None, extra_overrides=None):
    """Evaluate perplexity for Table 4 (OpenWebText)."""
    overrides = [
        "mode=ppl_eval",

        # TABLE 4 SPECIFIC

        "data=openwebtext-split",           # ← OWT dataset
        "data.cache_dir=/content/bd3lms/data",
        "data.streaming=true",
        "data.max_test_samples=500",        # Evaluation samples
        "model=tiny",
        "model.length=1024",                # ← 1024 context
        "model.attn_backend=sdpa",
        f"algo={algo}",
        f"eval.checkpoint_path={checkpoint_path}",
        "trainer.accelerator=gpu",
        "trainer.devices=1",
        "trainer.num_nodes=1",
        "trainer.precision=16-mixed",
        "trainer.num_sanity_val_steps=0",
        "wandb=null",
    ]
    overrides.extend(_small_loader_overrides(batch_size=4, num_workers=2))

    if block_size is not None:
        overrides.append(f"block_size={block_size}")
    if extra_overrides:
        overrides.extend(extra_overrides)

    log_text = run_main(overrides)
    ppl = extract_val_ppl(log_text)
    if ppl is None:
        raise ValueError("Could not parse val/ppl from output.")
    return ppl

# %%
results = []

# 1) AUTOREGRESSIVE BASELINE

print("=" * 60)
print("Training AR baseline...")
print("=" * 60)
ar_run = "ar_tiny_owt_len1024"
ar_ckpt = train_run(ar_run, algo="ar")
ar_ppl = eval_run(algo="ar", checkpoint_path=ar_ckpt)
results.append({"model": "Autoregressive", "block_size_Lprime": "-", "val_ppl": ar_ppl})
print(f" AR PPL: {ar_ppl}")


# 2) DIFFUSION BASELINES: SEDD + MDLM

for algo_name, display_name in [("sedd", "SEDD"), ("mdlm", "MDLM")]:

    print(f"Training {display_name} baseline...")

    run_name = f"{algo_name}_tiny_owt_len1024"
    ckpt = train_run(
        run_name,
        algo=algo_name,
        extra_overrides=[
            "training.resample=false",
            "algo.var_min=false",
            "algo.clip_search_widths=[]",
        ],
    )
    ppl = eval_run(
        algo=algo_name,
        checkpoint_path=ckpt,
        extra_overrides=[
            "algo.var_min=false",
        ],
    )
    results.append({"model": display_name, "block_size_Lprime": "-", "val_ppl": ppl})
    print(f"✓ {display_name} PPL: {ppl}")


# 3) BD3-LM BASE TRAINING (block_size = 1024 = L)


print("Training BD3-LM BASE (block_size=1024)...")

bd3lm_base_run = "bd3lm_base_owt_len1024"
bd3lm_base_ckpt = train_run(
    bd3lm_base_run,
    algo="bd3lm",
    block_size=1024,  # ← L' = L (full context for base)
    extra_overrides=[
        "training.resample=false",  # No resampling for base
        "algo.var_min=false",
        "algo.clip_search_widths=[]",
    ],
)
print(f"✓ BD3-LM base checkpoint saved")

# 4) BD3-LM FINE-TUNING (block_size = 16, 8, 4)

for Lprime in [16, 8, 4]:

    print(f"Fine-tuning BD3-LM (block_size={Lprime})...")

    finetune_run = f"bd3lm_finetune_owt_Lp{Lprime}"
    finetune_ckpt = train_run(
        finetune_run,
        algo="bd3lm",
        block_size=Lprime,
        from_pretrained=bd3lm_base_ckpt,  # ← Start from base!
        extra_overrides=[
            "training.resample=true",  # ← Enable resampling for fine-tune!
            "algo.var_min=false",
            "algo.clip_search_widths=[]",
        ],
    )
    ppl = eval_run(
        algo="bd3lm",
        checkpoint_path=finetune_ckpt,
        block_size=Lprime,
        extra_overrides=[
            "algo.var_min=false",
        ],
    )
    results.append({"model": "BD3-LM", "block_size_Lprime": Lprime, "val_ppl": ppl})
    print(f" BD3-LM (L'={Lprime}) PPL: {ppl}")

print("ALL EXPERIMENTS COMPLETE!")
# Out:
# ============================================================
# Training AR baseline...
# ============================================================
#
# $ /usr/bin/python3 -u bd3lms/main.py mode=train data=openwebtext-split data.cache_dir=/content/bd3lms/data data.streaming=true data.max_train_samples=2000 model=tiny model.length=1024 model.attn_backend=sdpa algo=ar trainer.accelerator=gpu trainer.devices=1 trainer.num_nodes=1 trainer.precision=16-mixed trainer.num_sanity_val_steps=0 trainer.log_every_n_steps=10 trainer.val_check_interval=10 trainer.max_steps=3000 data.max_valid_samples=100 data.max_test_samples=100 checkpointing.save_dir=/content/repro_runs/ar_tiny_owt_len1024 checkpointing.resume_from_ckpt=false wandb=null loader.global_batch_size=4 loader.eval_global_batch_size=4 loader.batch_size=4 loader.eval_batch_size=4 loader.num_workers=2 trainer.accumulate_grad_batches=1
#  this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  62%|██████▎   | 20/32 [00:00<00:00, 63.21it/s]
#
# Validation DataLoader 0: 100%|██████████| 32/32 [00:00<00:00, 64.22it/s]
#
#
# Epoch 5:  32%|███▏      | 180/560 [01:22<02:54,  2.18it/s, v_num=0]Epoch 5, global step 2980: 'val/nll' reached 5.91674 (best 5.91674), saving model to '/content/repro_runs/ar_tiny_owt_len1024/checkpoints/best.ckpt' as top 1
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  62%|██████▎   | 20/32 [00:00<00:00, 61.09it/s]
#
# Validation DataLoader 0: 100%|██████████| 32/32 [00:00<00:00, 62.20it/s]
#
#
# Epoch 5:  32%|███▏      | 180/560 [01:26<03:02,  2.08it/s, v_num=0]Epoch 5, global step 2990: 'val/nll' reached 5.91390 (best 5.91390), saving model to '/content/repro_runs/ar_tiny_owt_len1024/checkpoints/best.ckpt' as top 1
#
# Epoch 5:  36%|███▌      | 200/560 [01:29<02:41,  2.23it/s, v_num=0]
# Epoch 5:  36%|███▌      | 200/560 [01:29<02:41,  2.23it/s, v_num=0]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  62%|██████▎   | 20/32 [00:00<00:00, 58.07it/s]
#
# Validation DataLoader 0: 100%|██████████| 32/32 [00:00<00:00, 59.64it/s]
#
#
# Epoch 5:  36%|███▌      | 200/560 [01:35<02:51,  2.10it/s, v_num=0]Epoch 5, global step 3000: 'val/nll' reached 5.91123 (best 5.91123), saving model to '/content/repro_runs/ar_tiny_owt_len1024/checkpoints/best.ckpt' as top 1
#
# Epoch 5:  36%|███▌      | 200/560 [01:36<02:54,  2.06it/s, v_num=0]`Trainer.fit` stopped: `max_steps=3000` reached.
#
# Epoch 5:  36%|███▌      | 200/560 [01:36<02:54,  2.06it/s, v_num=0]
#
#
# $ /usr/bin/python3 -u bd3lms/main.py mode=ppl_eval data=openwebtext-split data.cache_dir=/content/bd3lms/data data.streaming=true data.max_test_samples=500 model=tiny model.length=1024 model.attn_backend=sdpa algo=ar eval.checkpoint_path=/content/repro_runs/ar_tiny_owt_len1024/checkpoints/last.ckpt trainer.accelerator=gpu trainer.devices=1 trainer.num_nodes=1 trainer.precision=16-mixed trainer.num_sanity_val_steps=0 wandb=null loader.global_batch_size=4 loader.eval_global_batch_size=4 loader.batch_size=4 loader.eval_batch_size=4 loader.num_workers=2 trainer.accumulate_grad_batches=1
# | 26740/27619 [06:31<00:12, 68.35it/s]
# Validation DataLoader 0:  97%|█████████▋| 26760/27619 [06:31<00:12, 68.35it/s]
# Validation DataLoader 0:  97%|█████████▋| 26780/27619 [06:31<00:12, 68.35it/s]
# Validation DataLoader 0:  97%|█████████▋| 26800/27619 [06:32<00:11, 68.35it/s]
# Validation DataLoader 0:  97%|█████████▋| 26820/27619 [06:32<00:11, 68.35it/s]
# Validation DataLoader 0:  97%|█████████▋| 26840/27619 [06:32<00:11, 68.36it/s]
# Validation DataLoader 0:  97%|█████████▋| 26860/27619 [06:32<00:11, 68.36it/s]
# Validation DataLoader 0:  97%|█████████▋| 26880/27619 [06:33<00:10, 68.36it/s]
# Validation DataLoader 0:  97%|█████████▋| 26900/27619 [06:33<00:10, 68.36it/s]
# Validation DataLoader 0:  97%|█████████▋| 26920/27619 [06:33<00:10, 68.36it/s]
# Validation DataLoader 0:  98%|█████████▊| 26940/27619 [06:34<00:09, 68.36it/s]
# Validation DataLoader 0:  98%|█████████▊| 26960/27619 [06:34<00:09, 68.36it/s]
# Validation DataLoader 0:  98%|█████████▊| 26980/27619 [06:34<00:09, 68.36it/s]
# Validation DataLoader 0:  98%|█████████▊| 27000/27619 [06:34<00:09, 68.37it/s]
# Validation DataLoader 0:  98%|█████████▊| 27020/27619 [06:35<00:08, 68.37it/s]
# Validation DataLoader 0:  98%|█████████▊| 27040/27619 [06:35<00:08, 68.37it/s]
# Validation DataLoader 0:  98%|█████████▊| 27060/27619 [06:35<00:08, 68.37it/s]
# Validation DataLoader 0:  98%|█████████▊| 27080/27619 [06:36<00:07, 68.37it/s]
# Validation DataLoader 0:  98%|█████████▊| 27100/27619 [06:36<00:07, 68.37it/s]
# Validation DataLoader 0:  98%|█████████▊| 27120/27619 [06:36<00:07, 68.37it/s]
# Validation DataLoader 0:  98%|█████████▊| 27140/27619 [06:36<00:07, 68.37it/s]
# Validation DataLoader 0:  98%|█████████▊| 27160/27619 [06:37<00:06, 68.37it/s]
# Validation DataLoader 0:  98%|█████████▊| 27180/27619 [06:37<00:06, 68.38it/s]
# Validation DataLoader 0:  98%|█████████▊| 27200/27619 [06:37<00:06, 68.38it/s]
# Validation DataLoader 0:  99%|█████████▊| 27220/27619 [06:38<00:05, 68.38it/s]
# Validation DataLoader 0:  99%|█████████▊| 27240/27619 [06:38<00:05, 68.38it/s]
# Validation DataLoader 0:  99%|█████████▊| 27260/27619 [06:38<00:05, 68.38it/s]
# Validation DataLoader 0:  99%|█████████▉| 27280/27619 [06:38<00:04, 68.38it/s]
# Validation DataLoader 0:  99%|█████████▉| 27300/27619 [06:39<00:04, 68.38it/s]
# Validation DataLoader 0:  99%|█████████▉| 27320/27619 [06:39<00:04, 68.38it/s]
# Validation DataLoader 0:  99%|█████████▉| 27340/27619 [06:39<00:04, 68.38it/s]
# Validation DataLoader 0:  99%|█████████▉| 27360/27619 [06:40<00:03, 68.38it/s]
# Validation DataLoader 0:  99%|█████████▉| 27380/27619 [06:40<00:03, 68.38it/s]
# Validation DataLoader 0:  99%|█████████▉| 27400/27619 [06:40<00:03, 68.37it/s]
# Validation DataLoader 0:  99%|█████████▉| 27420/27619 [06:41<00:02, 68.37it/s]
# Validation DataLoader 0:  99%|█████████▉| 27440/27619 [06:41<00:02, 68.38it/s]
# Validation DataLoader 0:  99%|█████████▉| 27460/27619 [06:41<00:02, 68.38it/s]
# Validation DataLoader 0:  99%|█████████▉| 27480/27619 [06:41<00:02, 68.38it/s]
# Validation DataLoader 0: 100%|█████████▉| 27500/27619 [06:42<00:01, 68.38it/s]
# Validation DataLoader 0: 100%|█████████▉| 27520/27619 [06:42<00:01, 68.38it/s]
# Validation DataLoader 0: 100%|█████████▉| 27540/27619 [06:42<00:01, 68.38it/s]
# Validation DataLoader 0: 100%|█████████▉| 27560/27619 [06:43<00:00, 68.38it/s]
# Validation DataLoader 0: 100%|█████████▉| 27580/27619 [06:43<00:00, 68.38it/s]
# Validation DataLoader 0: 100%|█████████▉| 27600/27619 [06:43<00:00, 68.38it/s]
# Validation DataLoader 0: 100%|██████████| 27619/27619 [06:43<00:00, 68.37it/s]
# Validation DataLoader 0: 100%|██████████| 27619/27619 [06:44<00:00, 68.36it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val/bpd          │     8.650932312011719     │
# │          val/nll          │     5.996369361877441     │
# │          val/ppl          │    401.96673583984375     │
# └───────────────────────────┴───────────────────────────┘
#
#  AR PPL: 401.96673583984375
# Training SEDD baseline...
#
# $ /usr/bin/python3 -u bd3lms/main.py mode=train data=openwebtext-split data.cache_dir=/content/bd3lms/data data.streaming=true data.max_train_samples=2000 model=tiny model.length=1024 model.attn_backend=sdpa algo=sedd trainer.accelerator=gpu trainer.devices=1 trainer.num_nodes=1 trainer.precision=16-mixed trainer.num_sanity_val_steps=0 trainer.log_every_n_steps=10 trainer.val_check_interval=10 trainer.max_steps=3000 data.max_valid_samples=100 data.max_test_samples=100 checkpointing.save_dir=/content/repro_runs/sedd_tiny_owt_len1024 checkpointing.resume_from_ckpt=false wandb=null loader.global_batch_size=4 loader.eval_global_batch_size=4 loader.batch_size=4 loader.eval_batch_size=4 loader.num_workers=2 trainer.accumulate_grad_batches=1 training.resample=false algo.var_min=false algo.clip_search_widths=[]
# l' was not in top 1
#
# Epoch 5:  32%|███▏      | 180/560 [00:54<01:54,  3.31it/s, v_num=0]
# Epoch 5:  32%|███▏      | 180/560 [00:54<01:54,  3.31it/s, v_num=0]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  62%|██████▎   | 20/32 [00:00<00:00, 42.43it/s]
#
# Validation DataLoader 0: 100%|██████████| 32/32 [00:00<00:00, 43.24it/s]
#
#
# Epoch 5:  32%|███▏      | 180/560 [00:55<01:56,  3.26it/s, v_num=0]Epoch 5, global step 2980: 'val/nll' was not in top 1
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  62%|██████▎   | 20/32 [00:00<00:00, 42.22it/s]
#
# Validation DataLoader 0: 100%|██████████| 32/32 [00:00<00:00, 42.85it/s]
#
#
# Epoch 5:  32%|███▏      | 180/560 [00:58<02:03,  3.08it/s, v_num=0]Epoch 5, global step 2990: 'val/nll' was not in top 1
#
# Epoch 5:  36%|███▌      | 200/560 [01:00<01:49,  3.30it/s, v_num=0]
# Epoch 5:  36%|███▌      | 200/560 [01:00<01:49,  3.30it/s, v_num=0]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  62%|██████▎   | 20/32 [00:00<00:00, 41.42it/s]
#
# Validation DataLoader 0: 100%|██████████| 32/32 [00:00<00:00, 42.03it/s]
#
#
# Epoch 5:  36%|███▌      | 200/560 [01:05<01:57,  3.06it/s, v_num=0]Epoch 5, global step 3000: 'val/nll' was not in top 1
#
# Epoch 5:  36%|███▌      | 200/560 [01:05<01:57,  3.06it/s, v_num=0]`Trainer.fit` stopped: `max_steps=3000` reached.
#
# Epoch 5:  36%|███▌      | 200/560 [01:05<01:57,  3.06it/s, v_num=0]
#
#
# $ /usr/bin/python3 -u bd3lms/main.py mode=ppl_eval data=openwebtext-split data.cache_dir=/content/bd3lms/data data.streaming=true data.max_test_samples=500 model=tiny model.length=1024 model.attn_backend=sdpa algo=sedd eval.checkpoint_path=/content/repro_runs/sedd_tiny_owt_len1024/checkpoints/last.ckpt trainer.accelerator=gpu trainer.devices=1 trainer.num_nodes=1 trainer.precision=16-mixed trainer.num_sanity_val_steps=0 wandb=null loader.global_batch_size=4 loader.eval_global_batch_size=4 loader.batch_size=4 loader.eval_batch_size=4 loader.num_workers=2 trainer.accumulate_grad_batches=1 algo.var_min=false
# | 26740/27619 [09:32<00:18, 46.70it/s]
# Validation DataLoader 0:  97%|█████████▋| 26760/27619 [09:33<00:18, 46.70it/s]
# Validation DataLoader 0:  97%|█████████▋| 26780/27619 [09:33<00:17, 46.70it/s]
# Validation DataLoader 0:  97%|█████████▋| 26800/27619 [09:33<00:17, 46.70it/s]
# Validation DataLoader 0:  97%|█████████▋| 26820/27619 [09:34<00:17, 46.70it/s]
# Validation DataLoader 0:  97%|█████████▋| 26840/27619 [09:34<00:16, 46.70it/s]
# Validation DataLoader 0:  97%|█████████▋| 26860/27619 [09:35<00:16, 46.70it/s]
# Validation DataLoader 0:  97%|█████████▋| 26880/27619 [09:35<00:15, 46.70it/s]
# Validation DataLoader 0:  97%|█████████▋| 26900/27619 [09:35<00:15, 46.71it/s]
# Validation DataLoader 0:  97%|█████████▋| 26920/27619 [09:36<00:14, 46.71it/s]
# Validation DataLoader 0:  98%|█████████▊| 26940/27619 [09:36<00:14, 46.71it/s]
# Validation DataLoader 0:  98%|█████████▊| 26960/27619 [09:37<00:14, 46.71it/s]
# Validation DataLoader 0:  98%|█████████▊| 26980/27619 [09:37<00:13, 46.71it/s]
# Validation DataLoader 0:  98%|█████████▊| 27000/27619 [09:38<00:13, 46.71it/s]
# Validation DataLoader 0:  98%|█████████▊| 27020/27619 [09:38<00:12, 46.71it/s]
# Validation DataLoader 0:  98%|█████████▊| 27040/27619 [09:38<00:12, 46.71it/s]
# Validation DataLoader 0:  98%|█████████▊| 27060/27619 [09:39<00:11, 46.71it/s]
# Validation DataLoader 0:  98%|█████████▊| 27080/27619 [09:39<00:11, 46.71it/s]
# Validation DataLoader 0:  98%|█████████▊| 27100/27619 [09:40<00:11, 46.71it/s]
# Validation DataLoader 0:  98%|█████████▊| 27120/27619 [09:40<00:10, 46.71it/s]
# Validation DataLoader 0:  98%|█████████▊| 27140/27619 [09:41<00:10, 46.71it/s]
# Validation DataLoader 0:  98%|█████████▊| 27160/27619 [09:41<00:09, 46.71it/s]
# Validation DataLoader 0:  98%|█████████▊| 27180/27619 [09:41<00:09, 46.71it/s]
# Validation DataLoader 0:  98%|█████████▊| 27200/27619 [09:42<00:08, 46.71it/s]
# Validation DataLoader 0:  99%|█████████▊| 27220/27619 [09:42<00:08, 46.71it/s]
# Validation DataLoader 0:  99%|█████████▊| 27240/27619 [09:43<00:08, 46.71it/s]
# Validation DataLoader 0:  99%|█████████▊| 27260/27619 [09:43<00:07, 46.71it/s]
# Validation DataLoader 0:  99%|█████████▉| 27280/27619 [09:44<00:07, 46.71it/s]
# Validation DataLoader 0:  99%|█████████▉| 27300/27619 [09:44<00:06, 46.71it/s]
# Validation DataLoader 0:  99%|█████████▉| 27320/27619 [09:44<00:06, 46.71it/s]
# Validation DataLoader 0:  99%|█████████▉| 27340/27619 [09:45<00:05, 46.71it/s]
# Validation DataLoader 0:  99%|█████████▉| 27360/27619 [09:45<00:05, 46.71it/s]
# Validation DataLoader 0:  99%|█████████▉| 27380/27619 [09:46<00:05, 46.71it/s]
# Validation DataLoader 0:  99%|█████████▉| 27400/27619 [09:46<00:04, 46.71it/s]
# Validation DataLoader 0:  99%|█████████▉| 27420/27619 [09:47<00:04, 46.71it/s]
# Validation DataLoader 0:  99%|█████████▉| 27440/27619 [09:47<00:03, 46.71it/s]
# Validation DataLoader 0:  99%|█████████▉| 27460/27619 [09:47<00:03, 46.71it/s]
# Validation DataLoader 0:  99%|█████████▉| 27480/27619 [09:48<00:02, 46.71it/s]
# Validation DataLoader 0: 100%|█████████▉| 27500/27619 [09:48<00:02, 46.71it/s]
# Validation DataLoader 0: 100%|█████████▉| 27520/27619 [09:49<00:02, 46.71it/s]
# Validation DataLoader 0: 100%|█████████▉| 27540/27619 [09:49<00:01, 46.71it/s]
# Validation DataLoader 0: 100%|█████████▉| 27560/27619 [09:50<00:01, 46.71it/s]
# Validation DataLoader 0: 100%|█████████▉| 27580/27619 [09:50<00:00, 46.71it/s]
# Validation DataLoader 0: 100%|█████████▉| 27600/27619 [09:50<00:00, 46.71it/s]
# Validation DataLoader 0: 100%|██████████| 27619/27619 [09:51<00:00, 46.70it/s]
# Validation DataLoader 0: 100%|██████████| 27619/27619 [09:51<00:00, 46.70it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val/bpd          │     9.167566299438477     │
# │          val/nll          │     6.354473114013672     │
# │          val/ppl          │     575.0592651367188     │
# └───────────────────────────┴───────────────────────────┘
#
# ✓ SEDD PPL: 575.0592651367188
# Training MDLM baseline...
#
# $ /usr/bin/python3 -u bd3lms/main.py mode=train data=openwebtext-split data.cache_dir=/content/bd3lms/data data.streaming=true data.max_train_samples=2000 model=tiny model.length=1024 model.attn_backend=sdpa algo=mdlm trainer.accelerator=gpu trainer.devices=1 trainer.num_nodes=1 trainer.precision=16-mixed trainer.num_sanity_val_steps=0 trainer.log_every_n_steps=10 trainer.val_check_interval=10 trainer.max_steps=3000 data.max_valid_samples=100 data.max_test_samples=100 checkpointing.save_dir=/content/repro_runs/mdlm_tiny_owt_len1024 checkpointing.resume_from_ckpt=false wandb=null loader.global_batch_size=4 loader.eval_global_batch_size=4 loader.batch_size=4 loader.eval_batch_size=4 loader.num_workers=2 trainer.accumulate_grad_batches=1 training.resample=false algo.var_min=false algo.clip_search_widths=[]
# l' was not in top 1
#
# Epoch 5:  32%|███▏      | 180/560 [00:57<02:02,  3.11it/s, v_num=0]
# Epoch 5:  32%|███▏      | 180/560 [00:57<02:02,  3.11it/s, v_num=0]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  62%|██████▎   | 20/32 [00:00<00:00, 38.12it/s]
#
# Validation DataLoader 0: 100%|██████████| 32/32 [00:00<00:00, 38.91it/s]
#
#
# Epoch 5:  32%|███▏      | 180/560 [00:58<02:04,  3.06it/s, v_num=0]Epoch 5, global step 2980: 'val/nll' was not in top 1
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  62%|██████▎   | 20/32 [00:00<00:00, 39.10it/s]
#
# Validation DataLoader 0: 100%|██████████| 32/32 [00:00<00:00, 39.87it/s]
#
#
# Epoch 5:  32%|███▏      | 180/560 [01:01<02:10,  2.90it/s, v_num=0]Epoch 5, global step 2990: 'val/nll' was not in top 1
#
# Epoch 5:  36%|███▌      | 200/560 [01:04<01:55,  3.12it/s, v_num=0]
# Epoch 5:  36%|███▌      | 200/560 [01:04<01:55,  3.12it/s, v_num=0]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  62%|██████▎   | 20/32 [00:00<00:00, 38.21it/s]
#
# Validation DataLoader 0: 100%|██████████| 32/32 [00:00<00:00, 39.08it/s]
#
#
# Epoch 5:  36%|███▌      | 200/560 [01:08<02:03,  2.92it/s, v_num=0]Epoch 5, global step 3000: 'val/nll' was not in top 1
#
# Epoch 5:  36%|███▌      | 200/560 [01:08<02:03,  2.92it/s, v_num=0]`Trainer.fit` stopped: `max_steps=3000` reached.
#
# Epoch 5:  36%|███▌      | 200/560 [01:08<02:03,  2.92it/s, v_num=0]
#
#
# $ /usr/bin/python3 -u bd3lms/main.py mode=ppl_eval data=openwebtext-split data.cache_dir=/content/bd3lms/data data.streaming=true data.max_test_samples=500 model=tiny model.length=1024 model.attn_backend=sdpa algo=mdlm eval.checkpoint_path=/content/repro_runs/mdlm_tiny_owt_len1024/checkpoints/last.ckpt trainer.accelerator=gpu trainer.devices=1 trainer.num_nodes=1 trainer.precision=16-mixed trainer.num_sanity_val_steps=0 wandb=null loader.global_batch_size=4 loader.eval_global_batch_size=4 loader.batch_size=4 loader.eval_batch_size=4 loader.num_workers=2 trainer.accumulate_grad_batches=1 algo.var_min=false
# | 26740/27619 [10:21<00:20, 43.02it/s]
# Validation DataLoader 0:  97%|█████████▋| 26760/27619 [10:21<00:19, 43.02it/s]
# Validation DataLoader 0:  97%|█████████▋| 26780/27619 [10:22<00:19, 43.02it/s]
# Validation DataLoader 0:  97%|█████████▋| 26800/27619 [10:22<00:19, 43.02it/s]
# Validation DataLoader 0:  97%|█████████▋| 26820/27619 [10:23<00:18, 43.02it/s]
# Validation DataLoader 0:  97%|█████████▋| 26840/27619 [10:23<00:18, 43.03it/s]
# Validation DataLoader 0:  97%|█████████▋| 26860/27619 [10:24<00:17, 43.03it/s]
# Validation DataLoader 0:  97%|█████████▋| 26880/27619 [10:24<00:17, 43.03it/s]
# Validation DataLoader 0:  97%|█████████▋| 26900/27619 [10:25<00:16, 43.03it/s]
# Validation DataLoader 0:  97%|█████████▋| 26920/27619 [10:25<00:16, 43.03it/s]
# Validation DataLoader 0:  98%|█████████▊| 26940/27619 [10:26<00:15, 43.03it/s]
# Validation DataLoader 0:  98%|█████████▊| 26960/27619 [10:26<00:15, 43.03it/s]
# Validation DataLoader 0:  98%|█████████▊| 26980/27619 [10:27<00:14, 43.03it/s]
# Validation DataLoader 0:  98%|█████████▊| 27000/27619 [10:27<00:14, 43.03it/s]
# Validation DataLoader 0:  98%|█████████▊| 27020/27619 [10:27<00:13, 43.03it/s]
# Validation DataLoader 0:  98%|█████████▊| 27040/27619 [10:28<00:13, 43.03it/s]
# Validation DataLoader 0:  98%|█████████▊| 27060/27619 [10:28<00:12, 43.03it/s]
# Validation DataLoader 0:  98%|█████████▊| 27080/27619 [10:29<00:12, 43.03it/s]
# Validation DataLoader 0:  98%|█████████▊| 27100/27619 [10:29<00:12, 43.03it/s]
# Validation DataLoader 0:  98%|█████████▊| 27120/27619 [10:30<00:11, 43.03it/s]
# Validation DataLoader 0:  98%|█████████▊| 27140/27619 [10:30<00:11, 43.03it/s]
# Validation DataLoader 0:  98%|█████████▊| 27160/27619 [10:31<00:10, 43.03it/s]
# Validation DataLoader 0:  98%|█████████▊| 27180/27619 [10:31<00:10, 43.03it/s]
# Validation DataLoader 0:  98%|█████████▊| 27200/27619 [10:32<00:09, 43.03it/s]
# Validation DataLoader 0:  99%|█████████▊| 27220/27619 [10:32<00:09, 43.03it/s]
# Validation DataLoader 0:  99%|█████████▊| 27240/27619 [10:33<00:08, 43.03it/s]
# Validation DataLoader 0:  99%|█████████▊| 27260/27619 [10:33<00:08, 43.03it/s]
# Validation DataLoader 0:  99%|█████████▉| 27280/27619 [10:34<00:07, 43.03it/s]
# Validation DataLoader 0:  99%|█████████▉| 27300/27619 [10:34<00:07, 43.03it/s]
# Validation DataLoader 0:  99%|█████████▉| 27320/27619 [10:34<00:06, 43.03it/s]
# Validation DataLoader 0:  99%|█████████▉| 27340/27619 [10:35<00:06, 43.03it/s]
# Validation DataLoader 0:  99%|█████████▉| 27360/27619 [10:35<00:06, 43.02it/s]
# Validation DataLoader 0:  99%|█████████▉| 27380/27619 [10:36<00:05, 43.02it/s]
# Validation DataLoader 0:  99%|█████████▉| 27400/27619 [10:36<00:05, 43.02it/s]
# Validation DataLoader 0:  99%|█████████▉| 27420/27619 [10:37<00:04, 43.02it/s]
# Validation DataLoader 0:  99%|█████████▉| 27440/27619 [10:37<00:04, 43.02it/s]
# Validation DataLoader 0:  99%|█████████▉| 27460/27619 [10:38<00:03, 43.02it/s]
# Validation DataLoader 0:  99%|█████████▉| 27480/27619 [10:38<00:03, 43.02it/s]
# Validation DataLoader 0: 100%|█████████▉| 27500/27619 [10:39<00:02, 43.02it/s]
# Validation DataLoader 0: 100%|█████████▉| 27520/27619 [10:39<00:02, 43.02it/s]
# Validation DataLoader 0: 100%|█████████▉| 27540/27619 [10:40<00:01, 43.01it/s]
# Validation DataLoader 0: 100%|█████████▉| 27560/27619 [10:40<00:01, 43.01it/s]
# Validation DataLoader 0: 100%|█████████▉| 27580/27619 [10:41<00:00, 43.02it/s]
# Validation DataLoader 0: 100%|█████████▉| 27600/27619 [10:41<00:00, 43.02it/s]
# Validation DataLoader 0: 100%|██████████| 27619/27619 [10:42<00:00, 43.01it/s]
# Validation DataLoader 0: 100%|██████████| 27619/27619 [10:42<00:00, 43.01it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val/bpd          │     9.201790809631348     │
# │          val/nll          │     6.378195285797119     │
# │          val/ppl          │     588.8640747070312     │
# └───────────────────────────┴───────────────────────────┘
#
# ✓ MDLM PPL: 588.8640747070312
# Training BD3-LM BASE (block_size=1024)...
#
# $ /usr/bin/python3 -u bd3lms/main.py mode=train data=openwebtext-split data.cache_dir=/content/bd3lms/data data.streaming=true data.max_train_samples=2000 model=tiny model.length=1024 model.attn_backend=sdpa algo=bd3lm trainer.accelerator=gpu trainer.devices=1 trainer.num_nodes=1 trainer.precision=16-mixed trainer.num_sanity_val_steps=0 trainer.log_every_n_steps=10 trainer.val_check_interval=10 trainer.max_steps=3000 data.max_valid_samples=100 data.max_test_samples=100 checkpointing.save_dir=/content/repro_runs/bd3lm_base_owt_len1024 checkpointing.resume_from_ckpt=false wandb=null loader.global_batch_size=4 loader.eval_global_batch_size=4 loader.batch_size=4 loader.eval_batch_size=4 loader.num_workers=2 trainer.accumulate_grad_batches=1 block_size=1024 training.resample=false algo.var_min=false algo.clip_search_widths=[]
# l' was not in top 1
#
# Epoch 5:  32%|███▏      | 180/560 [01:04<02:16,  2.79it/s, v_num=0]
# Epoch 5:  32%|███▏      | 180/560 [01:04<02:16,  2.79it/s, v_num=0]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  62%|██████▎   | 20/32 [00:00<00:00, 33.64it/s]
#
# Validation DataLoader 0: 100%|██████████| 32/32 [00:00<00:00, 34.10it/s]
#
#
# Epoch 5:  32%|███▏      | 180/560 [01:05<02:18,  2.74it/s, v_num=0]Epoch 5, global step 2980: 'val/nll' was not in top 1
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  62%|██████▎   | 20/32 [00:00<00:00, 33.22it/s]
#
# Validation DataLoader 0: 100%|██████████| 32/32 [00:00<00:00, 33.81it/s]
#
#
# Epoch 5:  32%|███▏      | 180/560 [01:09<02:26,  2.59it/s, v_num=0]Epoch 5, global step 2990: 'val/nll' was not in top 1
#
# Epoch 5:  36%|███▌      | 200/560 [01:12<02:09,  2.78it/s, v_num=0]
# Epoch 5:  36%|███▌      | 200/560 [01:12<02:09,  2.78it/s, v_num=0]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  62%|██████▎   | 20/32 [00:00<00:00, 32.93it/s]
#
# Validation DataLoader 0: 100%|██████████| 32/32 [00:00<00:00, 33.69it/s]
#
#
# Epoch 5:  36%|███▌      | 200/560 [01:15<02:16,  2.63it/s, v_num=0]Epoch 5, global step 3000: 'val/nll' was not in top 1
#
# Epoch 5:  36%|███▌      | 200/560 [01:15<02:16,  2.63it/s, v_num=0]`Trainer.fit` stopped: `max_steps=3000` reached.
#
# Epoch 5:  36%|███▌      | 200/560 [01:15<02:16,  2.63it/s, v_num=0]
#
# ✓ BD3-LM base checkpoint saved
# Fine-tuning BD3-LM (block_size=16)...
#
# $ /usr/bin/python3 -u bd3lms/main.py mode=train data=openwebtext-split data.cache_dir=/content/bd3lms/data data.streaming=true data.max_train_samples=2000 model=tiny model.length=1024 model.attn_backend=sdpa algo=bd3lm trainer.accelerator=gpu trainer.devices=1 trainer.num_nodes=1 trainer.precision=16-mixed trainer.num_sanity_val_steps=0 trainer.log_every_n_steps=10 trainer.val_check_interval=10 trainer.max_steps=3000 data.max_valid_samples=100 data.max_test_samples=100 checkpointing.save_dir=/content/repro_runs/bd3lm_finetune_owt_Lp16 checkpointing.resume_from_ckpt=false wandb=null loader.global_batch_size=4 loader.eval_global_batch_size=4 loader.batch_size=4 loader.eval_batch_size=4 loader.num_workers=2 trainer.accumulate_grad_batches=1 block_size=16 training.from_pretrained=/content/repro_runs/bd3lm_base_owt_len1024/checkpoints/last.ckpt training.resample=true algo.var_min=false algo.clip_search_widths=[]
# l' was not in top 1
#
# Epoch 5:  68%|██████▊   | 380/560 [02:20<01:06,  2.71it/s, v_num=0]
# Epoch 5:  68%|██████▊   | 380/560 [02:20<01:06,  2.71it/s, v_num=0]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  62%|██████▎   | 20/32 [00:00<00:00, 31.00it/s]
#
# Validation DataLoader 0: 100%|██████████| 32/32 [00:01<00:00, 31.84it/s]
#
#
# Epoch 5:  68%|██████▊   | 380/560 [02:21<01:06,  2.69it/s, v_num=0]Epoch 5, global step 2980: 'val/nll' was not in top 1
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  62%|██████▎   | 20/32 [00:00<00:00, 32.11it/s]
#
# Validation DataLoader 0: 100%|██████████| 32/32 [00:00<00:00, 32.77it/s]
#
#
# Epoch 5:  68%|██████▊   | 380/560 [02:24<01:08,  2.62it/s, v_num=0]Epoch 5, global step 2990: 'val/nll' was not in top 1
#
# Epoch 5:  71%|███████▏  | 400/560 [02:27<00:58,  2.71it/s, v_num=0]
# Epoch 5:  71%|███████▏  | 400/560 [02:27<00:58,  2.71it/s, v_num=0]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  62%|██████▎   | 20/32 [00:00<00:00, 30.52it/s]
#
# Validation DataLoader 0: 100%|██████████| 32/32 [00:01<00:00, 31.31it/s]
#
#
# Epoch 5:  71%|███████▏  | 400/560 [02:31<01:00,  2.64it/s, v_num=0]Epoch 5, global step 3000: 'val/nll' was not in top 1
#
# Epoch 5:  71%|███████▏  | 400/560 [02:31<01:00,  2.64it/s, v_num=0]`Trainer.fit` stopped: `max_steps=3000` reached.
#
# Epoch 5:  71%|███████▏  | 400/560 [02:31<01:00,  2.64it/s, v_num=0]
#
#
# $ /usr/bin/python3 -u bd3lms/main.py mode=ppl_eval data=openwebtext-split data.cache_dir=/content/bd3lms/data data.streaming=true data.max_test_samples=500 model=tiny model.length=1024 model.attn_backend=sdpa algo=bd3lm eval.checkpoint_path=/content/repro_runs/bd3lm_finetune_owt_Lp16/checkpoints/last.ckpt trainer.accelerator=gpu trainer.devices=1 trainer.num_nodes=1 trainer.precision=16-mixed trainer.num_sanity_val_steps=0 wandb=null loader.global_batch_size=4 loader.eval_global_batch_size=4 loader.batch_size=4 loader.eval_batch_size=4 loader.num_workers=2 trainer.accumulate_grad_batches=1 block_size=16 algo.var_min=false
# | 26740/27619 [12:14<00:24, 36.42it/s]
# Validation DataLoader 0:  97%|█████████▋| 26760/27619 [12:14<00:23, 36.42it/s]
# Validation DataLoader 0:  97%|█████████▋| 26780/27619 [12:15<00:23, 36.42it/s]
# Validation DataLoader 0:  97%|█████████▋| 26800/27619 [12:15<00:22, 36.42it/s]
# Validation DataLoader 0:  97%|█████████▋| 26820/27619 [12:16<00:21, 36.42it/s]
# Validation DataLoader 0:  97%|█████████▋| 26840/27619 [12:16<00:21, 36.42it/s]
# Validation DataLoader 0:  97%|█████████▋| 26860/27619 [12:17<00:20, 36.42it/s]
# Validation DataLoader 0:  97%|█████████▋| 26880/27619 [12:17<00:20, 36.42it/s]
# Validation DataLoader 0:  97%|█████████▋| 26900/27619 [12:18<00:19, 36.42it/s]
# Validation DataLoader 0:  97%|█████████▋| 26920/27619 [12:19<00:19, 36.42it/s]
# Validation DataLoader 0:  98%|█████████▊| 26940/27619 [12:19<00:18, 36.42it/s]
# Validation DataLoader 0:  98%|█████████▊| 26960/27619 [12:20<00:18, 36.42it/s]
# Validation DataLoader 0:  98%|█████████▊| 26980/27619 [12:20<00:17, 36.42it/s]
# Validation DataLoader 0:  98%|█████████▊| 27000/27619 [12:21<00:16, 36.42it/s]
# Validation DataLoader 0:  98%|█████████▊| 27020/27619 [12:21<00:16, 36.42it/s]
# Validation DataLoader 0:  98%|█████████▊| 27040/27619 [12:22<00:15, 36.42it/s]
# Validation DataLoader 0:  98%|█████████▊| 27060/27619 [12:23<00:15, 36.42it/s]
# Validation DataLoader 0:  98%|█████████▊| 27080/27619 [12:23<00:14, 36.42it/s]
# Validation DataLoader 0:  98%|█████████▊| 27100/27619 [12:24<00:14, 36.42it/s]
# Validation DataLoader 0:  98%|█████████▊| 27120/27619 [12:24<00:13, 36.42it/s]
# Validation DataLoader 0:  98%|█████████▊| 27140/27619 [12:25<00:13, 36.42it/s]
# Validation DataLoader 0:  98%|█████████▊| 27160/27619 [12:25<00:12, 36.42it/s]
# Validation DataLoader 0:  98%|█████████▊| 27180/27619 [12:26<00:12, 36.42it/s]
# Validation DataLoader 0:  98%|█████████▊| 27200/27619 [12:26<00:11, 36.42it/s]
# Validation DataLoader 0:  99%|█████████▊| 27220/27619 [12:27<00:10, 36.42it/s]
# Validation DataLoader 0:  99%|█████████▊| 27240/27619 [12:28<00:10, 36.42it/s]
# Validation DataLoader 0:  99%|█████████▊| 27260/27619 [12:28<00:09, 36.42it/s]
# Validation DataLoader 0:  99%|█████████▉| 27280/27619 [12:29<00:09, 36.42it/s]
# Validation DataLoader 0:  99%|█████████▉| 27300/27619 [12:29<00:08, 36.42it/s]
# Validation DataLoader 0:  99%|█████████▉| 27320/27619 [12:30<00:08, 36.41it/s]
# Validation DataLoader 0:  99%|█████████▉| 27340/27619 [12:30<00:07, 36.41it/s]
# Validation DataLoader 0:  99%|█████████▉| 27360/27619 [12:31<00:07, 36.41it/s]
# Validation DataLoader 0:  99%|█████████▉| 27380/27619 [12:31<00:06, 36.41it/s]
# Validation DataLoader 0:  99%|█████████▉| 27400/27619 [12:32<00:06, 36.41it/s]
# Validation DataLoader 0:  99%|█████████▉| 27420/27619 [12:32<00:05, 36.41it/s]
# Validation DataLoader 0:  99%|█████████▉| 27440/27619 [12:33<00:04, 36.41it/s]
# Validation DataLoader 0:  99%|█████████▉| 27460/27619 [12:34<00:04, 36.41it/s]
# Validation DataLoader 0:  99%|█████████▉| 27480/27619 [12:34<00:03, 36.41it/s]
# Validation DataLoader 0: 100%|█████████▉| 27500/27619 [12:35<00:03, 36.41it/s]
# Validation DataLoader 0: 100%|█████████▉| 27520/27619 [12:35<00:02, 36.41it/s]
# Validation DataLoader 0: 100%|█████████▉| 27540/27619 [12:36<00:02, 36.41it/s]
# Validation DataLoader 0: 100%|█████████▉| 27560/27619 [12:36<00:01, 36.41it/s]
# Validation DataLoader 0: 100%|█████████▉| 27580/27619 [12:37<00:01, 36.41it/s]
# Validation DataLoader 0: 100%|█████████▉| 27600/27619 [12:37<00:00, 36.41it/s]
# Validation DataLoader 0: 100%|██████████| 27619/27619 [12:38<00:00, 36.41it/s]
# Validation DataLoader 0: 100%|██████████| 27619/27619 [12:38<00:00, 36.41it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val/bpd          │     8.776544570922852     │
# │          val/nll          │     6.083437442779541     │
# │          val/ppl          │     438.5340576171875     │
# └───────────────────────────┴───────────────────────────┘
#
#  BD3-LM (L'=16) PPL: 438.5340576171875
# Fine-tuning BD3-LM (block_size=8)...
#
# $ /usr/bin/python3 -u bd3lms/main.py mode=train data=openwebtext-split data.cache_dir=/content/bd3lms/data data.streaming=true data.max_train_samples=2000 model=tiny model.length=1024 model.attn_backend=sdpa algo=bd3lm trainer.accelerator=gpu trainer.devices=1 trainer.num_nodes=1 trainer.precision=16-mixed trainer.num_sanity_val_steps=0 trainer.log_every_n_steps=10 trainer.val_check_interval=10 trainer.max_steps=3000 data.max_valid_samples=100 data.max_test_samples=100 checkpointing.save_dir=/content/repro_runs/bd3lm_finetune_owt_Lp8 checkpointing.resume_from_ckpt=false wandb=null loader.global_batch_size=4 loader.eval_global_batch_size=4 loader.batch_size=4 loader.eval_batch_size=4 loader.num_workers=2 trainer.accumulate_grad_batches=1 block_size=8 training.from_pretrained=/content/repro_runs/bd3lm_base_owt_len1024/checkpoints/last.ckpt training.resample=true algo.var_min=false algo.clip_search_widths=[]
# l' was not in top 1
#
# Epoch 5:  68%|██████▊   | 380/560 [02:22<01:07,  2.67it/s, v_num=0]
# Epoch 5:  68%|██████▊   | 380/560 [02:22<01:07,  2.67it/s, v_num=0]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  62%|██████▎   | 20/32 [00:00<00:00, 33.20it/s]
#
# Validation DataLoader 0: 100%|██████████| 32/32 [00:00<00:00, 33.63it/s]
#
#
# Epoch 5:  68%|██████▊   | 380/560 [02:25<01:09,  2.61it/s, v_num=0]Epoch 5, global step 2980: 'val/nll' was not in top 1
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  62%|██████▎   | 20/32 [00:00<00:00, 31.88it/s]
#
# Validation DataLoader 0: 100%|██████████| 32/32 [00:00<00:00, 32.54it/s]
#
#
# Epoch 5:  68%|██████▊   | 380/560 [02:29<01:10,  2.54it/s, v_num=0]Epoch 5, global step 2990: 'val/nll' was not in top 1
#
# Epoch 5:  71%|███████▏  | 400/560 [02:31<01:00,  2.64it/s, v_num=0]
# Epoch 5:  71%|███████▏  | 400/560 [02:31<01:00,  2.64it/s, v_num=0]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  62%|██████▎   | 20/32 [00:00<00:00, 32.84it/s]
#
# Validation DataLoader 0: 100%|██████████| 32/32 [00:00<00:00, 33.51it/s]
#
#
# Epoch 5:  71%|███████▏  | 400/560 [02:35<01:02,  2.57it/s, v_num=0]Epoch 5, global step 3000: 'val/nll' was not in top 1
#
# Epoch 5:  71%|███████▏  | 400/560 [02:35<01:02,  2.57it/s, v_num=0]`Trainer.fit` stopped: `max_steps=3000` reached.
#
# Epoch 5:  71%|███████▏  | 400/560 [02:35<01:02,  2.57it/s, v_num=0]
#
#
# $ /usr/bin/python3 -u bd3lms/main.py mode=ppl_eval data=openwebtext-split data.cache_dir=/content/bd3lms/data data.streaming=true data.max_test_samples=500 model=tiny model.length=1024 model.attn_backend=sdpa algo=bd3lm eval.checkpoint_path=/content/repro_runs/bd3lm_finetune_owt_Lp8/checkpoints/last.ckpt trainer.accelerator=gpu trainer.devices=1 trainer.num_nodes=1 trainer.precision=16-mixed trainer.num_sanity_val_steps=0 wandb=null loader.global_batch_size=4 loader.eval_global_batch_size=4 loader.batch_size=4 loader.eval_batch_size=4 loader.num_workers=2 trainer.accumulate_grad_batches=1 block_size=8 algo.var_min=false
# | 26740/27619 [12:10<00:24, 36.59it/s]
# Validation DataLoader 0:  97%|█████████▋| 26760/27619 [12:11<00:23, 36.59it/s]
# Validation DataLoader 0:  97%|█████████▋| 26780/27619 [12:11<00:22, 36.59it/s]
# Validation DataLoader 0:  97%|█████████▋| 26800/27619 [12:12<00:22, 36.59it/s]
# Validation DataLoader 0:  97%|█████████▋| 26820/27619 [12:12<00:21, 36.59it/s]
# Validation DataLoader 0:  97%|█████████▋| 26840/27619 [12:13<00:21, 36.59it/s]
# Validation DataLoader 0:  97%|█████████▋| 26860/27619 [12:13<00:20, 36.59it/s]
# Validation DataLoader 0:  97%|█████████▋| 26880/27619 [12:14<00:20, 36.59it/s]
# Validation DataLoader 0:  97%|█████████▋| 26900/27619 [12:15<00:19, 36.60it/s]
# Validation DataLoader 0:  97%|█████████▋| 26920/27619 [12:15<00:19, 36.60it/s]
# Validation DataLoader 0:  98%|█████████▊| 26940/27619 [12:16<00:18, 36.60it/s]
# Validation DataLoader 0:  98%|█████████▊| 26960/27619 [12:16<00:18, 36.60it/s]
# Validation DataLoader 0:  98%|█████████▊| 26980/27619 [12:17<00:17, 36.60it/s]
# Validation DataLoader 0:  98%|█████████▊| 27000/27619 [12:17<00:16, 36.60it/s]
# Validation DataLoader 0:  98%|█████████▊| 27020/27619 [12:18<00:16, 36.60it/s]
# Validation DataLoader 0:  98%|█████████▊| 27040/27619 [12:18<00:15, 36.60it/s]
# Validation DataLoader 0:  98%|█████████▊| 27060/27619 [12:19<00:15, 36.60it/s]
# Validation DataLoader 0:  98%|█████████▊| 27080/27619 [12:19<00:14, 36.60it/s]
# Validation DataLoader 0:  98%|█████████▊| 27100/27619 [12:20<00:14, 36.60it/s]
# Validation DataLoader 0:  98%|█████████▊| 27120/27619 [12:21<00:13, 36.60it/s]
# Validation DataLoader 0:  98%|█████████▊| 27140/27619 [12:21<00:13, 36.60it/s]
# Validation DataLoader 0:  98%|█████████▊| 27160/27619 [12:22<00:12, 36.60it/s]
# Validation DataLoader 0:  98%|█████████▊| 27180/27619 [12:22<00:11, 36.60it/s]
# Validation DataLoader 0:  98%|█████████▊| 27200/27619 [12:23<00:11, 36.60it/s]
# Validation DataLoader 0:  99%|█████████▊| 27220/27619 [12:23<00:10, 36.60it/s]
# Validation DataLoader 0:  99%|█████████▊| 27240/27619 [12:24<00:10, 36.60it/s]
# Validation DataLoader 0:  99%|█████████▊| 27260/27619 [12:24<00:09, 36.60it/s]
# Validation DataLoader 0:  99%|█████████▉| 27280/27619 [12:25<00:09, 36.60it/s]
# Validation DataLoader 0:  99%|█████████▉| 27300/27619 [12:25<00:08, 36.60it/s]
# Validation DataLoader 0:  99%|█████████▉| 27320/27619 [12:26<00:08, 36.60it/s]
# Validation DataLoader 0:  99%|█████████▉| 27340/27619 [12:26<00:07, 36.60it/s]
# Validation DataLoader 0:  99%|█████████▉| 27360/27619 [12:27<00:07, 36.60it/s]
# Validation DataLoader 0:  99%|█████████▉| 27380/27619 [12:28<00:06, 36.60it/s]
# Validation DataLoader 0:  99%|█████████▉| 27400/27619 [12:28<00:05, 36.60it/s]
# Validation DataLoader 0:  99%|█████████▉| 27420/27619 [12:29<00:05, 36.60it/s]
# Validation DataLoader 0:  99%|█████████▉| 27440/27619 [12:29<00:04, 36.60it/s]
# Validation DataLoader 0:  99%|█████████▉| 27460/27619 [12:30<00:04, 36.60it/s]
# Validation DataLoader 0:  99%|█████████▉| 27480/27619 [12:30<00:03, 36.60it/s]
# Validation DataLoader 0: 100%|█████████▉| 27500/27619 [12:31<00:03, 36.60it/s]
# Validation DataLoader 0: 100%|█████████▉| 27520/27619 [12:31<00:02, 36.60it/s]
# Validation DataLoader 0: 100%|█████████▉| 27540/27619 [12:32<00:02, 36.60it/s]
# Validation DataLoader 0: 100%|█████████▉| 27560/27619 [12:32<00:01, 36.60it/s]
# Validation DataLoader 0: 100%|█████████▉| 27580/27619 [12:33<00:01, 36.60it/s]
# Validation DataLoader 0: 100%|█████████▉| 27600/27619 [12:34<00:00, 36.60it/s]
# Validation DataLoader 0: 100%|██████████| 27619/27619 [12:34<00:00, 36.60it/s]
# Validation DataLoader 0: 100%|██████████| 27619/27619 [12:34<00:00, 36.60it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val/bpd          │     8.758024215698242     │
# │          val/nll          │    6.0706000328063965     │
# │          val/ppl          │     432.9403991699219     │
# └───────────────────────────┴───────────────────────────┘
#
#  BD3-LM (L'=8) PPL: 432.9403991699219
# Fine-tuning BD3-LM (block_size=4)...
#
# $ /usr/bin/python3 -u bd3lms/main.py mode=train data=openwebtext-split data.cache_dir=/content/bd3lms/data data.streaming=true data.max_train_samples=2000 model=tiny model.length=1024 model.attn_backend=sdpa algo=bd3lm trainer.accelerator=gpu trainer.devices=1 trainer.num_nodes=1 trainer.precision=16-mixed trainer.num_sanity_val_steps=0 trainer.log_every_n_steps=10 trainer.val_check_interval=10 trainer.max_steps=3000 data.max_valid_samples=100 data.max_test_samples=100 checkpointing.save_dir=/content/repro_runs/bd3lm_finetune_owt_Lp4 checkpointing.resume_from_ckpt=false wandb=null loader.global_batch_size=4 loader.eval_global_batch_size=4 loader.batch_size=4 loader.eval_batch_size=4 loader.num_workers=2 trainer.accumulate_grad_batches=1 block_size=4 training.from_pretrained=/content/repro_runs/bd3lm_base_owt_len1024/checkpoints/last.ckpt training.resample=true algo.var_min=false algo.clip_search_widths=[]
# l' was not in top 1
#
# Epoch 5:  68%|██████▊   | 380/560 [02:18<01:05,  2.74it/s, v_num=0]
# Epoch 5:  68%|██████▊   | 380/560 [02:18<01:05,  2.74it/s, v_num=0]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  62%|██████▎   | 20/32 [00:00<00:00, 33.90it/s]
#
# Validation DataLoader 0: 100%|██████████| 32/32 [00:00<00:00, 34.15it/s]
#
#
# Epoch 5:  68%|██████▊   | 380/560 [02:19<01:06,  2.72it/s, v_num=0]Epoch 5, global step 2980: 'val/nll' was not in top 1
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  62%|██████▎   | 20/32 [00:00<00:00, 32.38it/s]
#
# Validation DataLoader 0: 100%|██████████| 32/32 [00:00<00:00, 33.11it/s]
#
#
# Epoch 5:  68%|██████▊   | 380/560 [02:24<01:08,  2.63it/s, v_num=0]Epoch 5, global step 2990: 'val/nll' was not in top 1
#
# Epoch 5:  71%|███████▏  | 400/560 [02:26<00:58,  2.72it/s, v_num=0]
# Epoch 5:  71%|███████▏  | 400/560 [02:26<00:58,  2.72it/s, v_num=0]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/32 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  62%|██████▎   | 20/32 [00:00<00:00, 33.14it/s]
#
# Validation DataLoader 0: 100%|██████████| 32/32 [00:00<00:00, 33.71it/s]
#
#
# Epoch 5:  71%|███████▏  | 400/560 [02:31<01:00,  2.64it/s, v_num=0]Epoch 5, global step 3000: 'val/nll' was not in top 1
#
# Epoch 5:  71%|███████▏  | 400/560 [02:31<01:00,  2.64it/s, v_num=0]`Trainer.fit` stopped: `max_steps=3000` reached.
#
# Epoch 5:  71%|███████▏  | 400/560 [02:31<01:00,  2.64it/s, v_num=0]
#
#
# $ /usr/bin/python3 -u bd3lms/main.py mode=ppl_eval data=openwebtext-split data.cache_dir=/content/bd3lms/data data.streaming=true data.max_test_samples=500 model=tiny model.length=1024 model.attn_backend=sdpa algo=bd3lm eval.checkpoint_path=/content/repro_runs/bd3lm_finetune_owt_Lp4/checkpoints/last.ckpt trainer.accelerator=gpu trainer.devices=1 trainer.num_nodes=1 trainer.precision=16-mixed trainer.num_sanity_val_steps=0 wandb=null loader.global_batch_size=4 loader.eval_global_batch_size=4 loader.batch_size=4 loader.eval_batch_size=4 loader.num_workers=2 trainer.accumulate_grad_batches=1 block_size=4 algo.var_min=false
# | 26740/27619 [12:15<00:24, 36.38it/s]
# Validation DataLoader 0:  97%|█████████▋| 26760/27619 [12:15<00:23, 36.38it/s]
# Validation DataLoader 0:  97%|█████████▋| 26780/27619 [12:16<00:23, 36.38it/s]
# Validation DataLoader 0:  97%|█████████▋| 26800/27619 [12:16<00:22, 36.38it/s]
# Validation DataLoader 0:  97%|█████████▋| 26820/27619 [12:17<00:21, 36.38it/s]
# Validation DataLoader 0:  97%|█████████▋| 26840/27619 [12:17<00:21, 36.38it/s]
# Validation DataLoader 0:  97%|█████████▋| 26860/27619 [12:18<00:20, 36.38it/s]
# Validation DataLoader 0:  97%|█████████▋| 26880/27619 [12:18<00:20, 36.38it/s]
# Validation DataLoader 0:  97%|█████████▋| 26900/27619 [12:19<00:19, 36.38it/s]
# Validation DataLoader 0:  97%|█████████▋| 26920/27619 [12:19<00:19, 36.38it/s]
# Validation DataLoader 0:  98%|█████████▊| 26940/27619 [12:20<00:18, 36.38it/s]
# Validation DataLoader 0:  98%|█████████▊| 26960/27619 [12:21<00:18, 36.38it/s]
# Validation DataLoader 0:  98%|█████████▊| 26980/27619 [12:21<00:17, 36.38it/s]
# Validation DataLoader 0:  98%|█████████▊| 27000/27619 [12:22<00:17, 36.38it/s]
# Validation DataLoader 0:  98%|█████████▊| 27020/27619 [12:22<00:16, 36.38it/s]
# Validation DataLoader 0:  98%|█████████▊| 27040/27619 [12:23<00:15, 36.38it/s]
# Validation DataLoader 0:  98%|█████████▊| 27060/27619 [12:23<00:15, 36.38it/s]
# Validation DataLoader 0:  98%|█████████▊| 27080/27619 [12:24<00:14, 36.38it/s]
# Validation DataLoader 0:  98%|█████████▊| 27100/27619 [12:24<00:14, 36.38it/s]
# Validation DataLoader 0:  98%|█████████▊| 27120/27619 [12:25<00:13, 36.38it/s]
# Validation DataLoader 0:  98%|█████████▊| 27140/27619 [12:25<00:13, 36.38it/s]
# Validation DataLoader 0:  98%|█████████▊| 27160/27619 [12:26<00:12, 36.38it/s]
# Validation DataLoader 0:  98%|█████████▊| 27180/27619 [12:27<00:12, 36.39it/s]
# Validation DataLoader 0:  98%|█████████▊| 27200/27619 [12:27<00:11, 36.39it/s]
# Validation DataLoader 0:  99%|█████████▊| 27220/27619 [12:28<00:10, 36.39it/s]
# Validation DataLoader 0:  99%|█████████▊| 27240/27619 [12:28<00:10, 36.39it/s]
# Validation DataLoader 0:  99%|█████████▊| 27260/27619 [12:29<00:09, 36.39it/s]
# Validation DataLoader 0:  99%|█████████▉| 27280/27619 [12:29<00:09, 36.39it/s]
# Validation DataLoader 0:  99%|█████████▉| 27300/27619 [12:30<00:08, 36.39it/s]
# Validation DataLoader 0:  99%|█████████▉| 27320/27619 [12:30<00:08, 36.39it/s]
# Validation DataLoader 0:  99%|█████████▉| 27340/27619 [12:31<00:07, 36.39it/s]
# Validation DataLoader 0:  99%|█████████▉| 27360/27619 [12:31<00:07, 36.39it/s]
# Validation DataLoader 0:  99%|█████████▉| 27380/27619 [12:32<00:06, 36.39it/s]
# Validation DataLoader 0:  99%|█████████▉| 27400/27619 [12:33<00:06, 36.39it/s]
# Validation DataLoader 0:  99%|█████████▉| 27420/27619 [12:33<00:05, 36.39it/s]
# Validation DataLoader 0:  99%|█████████▉| 27440/27619 [12:34<00:04, 36.39it/s]
# Validation DataLoader 0:  99%|█████████▉| 27460/27619 [12:34<00:04, 36.39it/s]
# Validation DataLoader 0:  99%|█████████▉| 27480/27619 [12:35<00:03, 36.39it/s]
# Validation DataLoader 0: 100%|█████████▉| 27500/27619 [12:35<00:03, 36.39it/s]
# Validation DataLoader 0: 100%|█████████▉| 27520/27619 [12:36<00:02, 36.39it/s]
# Validation DataLoader 0: 100%|█████████▉| 27540/27619 [12:36<00:02, 36.39it/s]
# Validation DataLoader 0: 100%|█████████▉| 27560/27619 [12:37<00:01, 36.39it/s]
# Validation DataLoader 0: 100%|█████████▉| 27580/27619 [12:37<00:01, 36.39it/s]
# Validation DataLoader 0: 100%|█████████▉| 27600/27619 [12:38<00:00, 36.39it/s]
# Validation DataLoader 0: 100%|██████████| 27619/27619 [12:38<00:00, 36.39it/s]
# Validation DataLoader 0: 100%|██████████| 27619/27619 [12:38<00:00, 36.39it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val/bpd          │     8.712620735168457     │
# │          val/nll          │     6.039128303527832     │
# │          val/ppl          │    419.52716064453125     │
# └───────────────────────────┴───────────────────────────┘
#
#  BD3-LM (L'=4) PPL: 419.52716064453125
# ALL EXPERIMENTS COMPLETE!
