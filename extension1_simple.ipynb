# %%
# !git clone -b Extension1 https://github.com/ntua-el21050/bd3lms.git
# Out:
# Cloning into 'bd3lms'...
# remote: Enumerating objects: 788, done.
# remote: Counting objects: 100% (246/246), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 788 (delta 214), reused 191 (delta 185), pack-reused 542 (from 1)
# Receiving objects: 100% (788/788), 2.40 MiB | 23.65 MiB/s, done.
# Resolving deltas: 100% (508/508), done.

# %%
# %%capture
# !pip install -r bd3lms/requirements.txt

# %%
import subprocess
import re
from pathlib import Path

def run_main(overrides, timeout=None):
    """Run `python -u main.py ...` and return combined stdout/stderr text."""
    env = dict(os.environ)
    env.setdefault("HYDRA_FULL_ERROR", "1")
    cmd = [sys.executable, "-u", "bd3lms/main.py", *overrides]
    print("\n$", " ".join(cmd))
    proc = subprocess.run(
        cmd,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True,
        timeout=timeout,
        check=False,
        env=env,
    )
    print(proc.stdout[-4000:])  # tail for quick visibility
    if proc.returncode != 0:
        raise RuntimeError(f"Command failed with return code {proc.returncode}")
    return proc.stdout

_METRIC_PATTERNS = [
    # Key: value (some loggers print this)
    re.compile(r"val/ppl\s*[:=]\s*([0-9]+(?:\.[0-9]+)?(?:e[+-]?\d+)?)", re.IGNORECASE),
    re.compile(r"'val/ppl'\s*:\s*([0-9]+(?:\.[0-9]+)?(?:e[+-]?\d+)?)", re.IGNORECASE),

    # Lightning "rich" table row (note the unicode box character │)
    re.compile(r"val/ppl\s*[│|]\s*([0-9]+(?:\.[0-9]+)?(?:e[+-]?\d+)?)", re.IGNORECASE),
]

def extract_val_ppl(log_text: str):
    # First try line-based parse from the end (most reliable for tables)
    for line in reversed(log_text.splitlines()):
        if "val/ppl" in line.lower():
            m = re.search(r"val/ppl.*?([0-9]+(?:\.[0-9]+)?(?:e[+-]?\d+)?)", line, re.IGNORECASE)
            if m:
                return float(m.group(1))

    # Fallback: scan entire text with known patterns
    hits = []
    for pat in _METRIC_PATTERNS:
        hits.extend(pat.findall(log_text))
    return float(hits[-1]) if hits else None

def _small_loader_overrides(batch_size=8, num_workers=2):
    """Overrides needed to avoid huge default batch sizes on Colab."""
    return [
        f"loader.global_batch_size={batch_size}",
        f"loader.eval_global_batch_size={batch_size}",
        f"loader.batch_size={batch_size}",
        f"loader.eval_batch_size={batch_size}",
        f"loader.num_workers={num_workers}",
        "trainer.accumulate_grad_batches=1",
    ]

def train_run(run_name, algo, block_size=None, from_pretrained=None, max_steps=800, extra_overrides=None):
    """Train a model (optionally from a base checkpoint) and return the last.ckpt path."""
    save_dir = Path("/content/repro_runs") / run_name
    if save_dir.exists():
        shutil.rmtree(save_dir)
    save_dir.mkdir(parents=True, exist_ok=True)

    overrides = [
        "mode=train",
        "data=lm1b-wrap",
        "data.cache_dir=/content/bd3lms/data",
        "data.streaming=true",
        "data.max_train_samples=5000",
        # For LM1B, validation uses the 'test' split in this codebase
        "model=tiny",
        "model.length=128",
        "model.attn_backend=sdpa",
        f"algo={algo}",
        "trainer.accelerator=gpu",
        "trainer.devices=1",
        "trainer.num_nodes=1",
        "trainer.precision=16-mixed",
        "trainer.num_sanity_val_steps=0",
        "trainer.log_every_n_steps=10",
        "trainer.val_check_interval=50",
        f"trainer.max_steps={max_steps}",
        "data.max_valid_samples=100",
        "data.max_test_samples=100",
        f"checkpointing.save_dir=/content/repro_runs/{run_name}",
        "checkpointing.resume_from_ckpt=false",
        "wandb=null",
    ]
    overrides.extend(_small_loader_overrides(batch_size=8, num_workers=2))
    if block_size is not None:
        overrides.append(f"block_size={block_size}")
    if from_pretrained is not None:
        overrides.append(f"training.from_pretrained={from_pretrained}")
    if extra_overrides:
        overrides.extend(extra_overrides)

    _ = run_main(overrides)
    ckpt = save_dir / "checkpoints" / "last.ckpt"
    if not ckpt.exists():
        raise FileNotFoundError(f"Expected checkpoint not found: {ckpt}")
    return str(ckpt)

def eval_run(algo, checkpoint_path, block_size=None, extra_overrides=None):
    """Evaluate perplexity (val/ppl) for a given checkpoint."""
    overrides = [
        "mode=ppl_eval",
        "data=lm1b-wrap",
        "data.cache_dir=/content/bd3lms/data",
        "data.streaming=true",
        # For LM1B, `get_dataloaders` maps validation to the 'test' split
        "data.max_test_samples=1000",
        "model=tiny",
        "model.length=128",
        "model.attn_backend=sdpa",
        f"algo={algo}",
        f"eval.checkpoint_path={checkpoint_path}",
        "trainer.accelerator=gpu",
        "trainer.devices=1",
        "trainer.num_nodes=1",
        "trainer.precision=16-mixed",
        "trainer.num_sanity_val_steps=0",
        "wandb=null",
    ]
    overrides.extend(_small_loader_overrides(batch_size=8, num_workers=2))
    if block_size is not None:
        overrides.append(f"block_size={block_size}")
    if extra_overrides:
        overrides.extend(extra_overrides)

    log_text = run_main(overrides)
    ppl = extract_val_ppl(log_text)
    if ppl is None:
        raise ValueError("Could not parse val/ppl from output. Try increasing the log tail or printing full logs.")
    return ppl

# %%
import os
import shutil
import sys

results = []

bd3lm_base_run = "bd3lm_base_len128"
bd3lm_base_ckpt = train_run(
    bd3lm_base_run,
    algo="bd3lm",
    block_size=128,
    extra_overrides=[
        "training.resample=false",
        "algo.var_min=false",
        "algo.clip_search_widths=[]",
    ],
)

for Lprime in [16, 8, 4]:
    finetune_run = f"bd3lm_finetune_Lp{Lprime}"
    finetune_ckpt = train_run(
        finetune_run,
        algo="bd3lm",
        block_size=Lprime,
        from_pretrained=bd3lm_base_ckpt,
        extra_overrides=[
            "training.resample=true",
            "algo.var_min=false",
            "algo.clip_search_widths=[]",
        ],
    )
    ppl = eval_run(
        algo="bd3lm",
        checkpoint_path=finetune_ckpt,
        block_size=Lprime,
        extra_overrides=[
            "algo.var_min=false",
        ],
    )
    results.append({"model": "Block diffusion (BD3LM)", "block_size_Lprime": Lprime, "val_ppl": ppl})
# Out:
# $ /usr/bin/python3 -u bd3lms/main.py mode=train data=lm1b-wrap data.cache_dir=/content/bd3lms/data data.streaming=true data.max_train_samples=5000 model=tiny model.length=128 model.attn_backend=sdpa algo=bd3lm trainer.accelerator=gpu trainer.devices=1 trainer.num_nodes=1 trainer.precision=16-mixed trainer.num_sanity_val_steps=0 trainer.log_every_n_steps=10 trainer.val_check_interval=50 trainer.max_steps=800 data.max_valid_samples=100 data.max_test_samples=100 checkpointing.save_dir=/content/repro_runs/bd3lm_base_len128 checkpointing.resume_from_ckpt=false wandb=null loader.global_batch_size=8 loader.eval_global_batch_size=8 loader.batch_size=8 loader.eval_batch_size=8 loader.num_workers=2 trainer.accumulate_grad_batches=1 block_size=128 training.resample=false algo.var_min=false algo.clip_search_widths=[]
# d 3.48549 (best 3.48549), saving model to '/content/repro_runs/bd3lm_base_len128/checkpoints/best.ckpt' as top 1
#
# Epoch 3:  82%|████████▏ | 120/146 [02:08<00:27,  0.93it/s, v_num=0]
# Epoch 3:  82%|████████▏ | 120/146 [02:08<00:27,  0.93it/s, v_num=0]
# Epoch 3:  96%|█████████▌| 140/146 [02:11<00:05,  1.07it/s, v_num=0]
# Epoch 3:  96%|█████████▌| 140/146 [02:11<00:05,  1.07it/s, v_num=0]
# Epoch 3: 100%|██████████| 146/146 [02:12<00:00,  1.10it/s, v_num=0]
# Epoch 3: 100%|██████████| 146/146 [02:12<00:00,  1.10it/s, v_num=0]
# Epoch 3: 100%|██████████| 146/146 [02:12<00:00,  1.10it/s, v_num=0]
# Epoch 3:   0%|          | 0/146 [00:00<?, ?it/s, v_num=0]
# Epoch 4:   0%|          | 0/146 [00:00<?, ?it/s, v_num=0]
# Epoch 4:  14%|█▎        | 20/146 [00:02<00:18,  6.94it/s, v_num=0]
# Epoch 4:  14%|█▎        | 20/146 [00:02<00:18,  6.94it/s, v_num=0]
# Epoch 4:  27%|██▋       | 40/146 [00:05<00:15,  6.90it/s, v_num=0]
# Epoch 4:  27%|██▋       | 40/146 [00:05<00:15,  6.90it/s, v_num=0]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 24.16it/s]
#
#
# Epoch 4:  27%|██▋       | 40/146 [00:07<00:19,  5.32it/s, v_num=0]Epoch 4, global step 634: 'val/nll' reached 3.44223 (best 3.44223), saving model to '/content/repro_runs/bd3lm_base_len128/checkpoints/best.ckpt' as top 1
#
# Epoch 4:  41%|████      | 60/146 [00:55<01:19,  1.08it/s, v_num=0]
# Epoch 4:  41%|████      | 60/146 [00:55<01:19,  1.08it/s, v_num=0]
# Epoch 4:  55%|█████▍    | 80/146 [00:58<00:48,  1.37it/s, v_num=0]
# Epoch 4:  55%|█████▍    | 80/146 [00:58<00:48,  1.37it/s, v_num=0]
# Epoch 4:  68%|██████▊   | 100/146 [01:01<00:28,  1.63it/s, v_num=0]
# Epoch 4:  68%|██████▊   | 100/146 [01:01<00:28,  1.63it/s, v_num=0]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 21.69it/s]
#
#
# Epoch 4:  68%|██████▊   | 100/146 [01:01<00:28,  1.62it/s, v_num=0]Epoch 4, global step 684: 'val/nll' was not in top 1
#
# Epoch 4:  82%|████████▏ | 120/146 [01:10<00:15,  1.71it/s, v_num=0]
# Epoch 4:  82%|████████▏ | 120/146 [01:10<00:15,  1.71it/s, v_num=0]
# Epoch 4:  96%|█████████▌| 140/146 [01:12<00:03,  1.92it/s, v_num=0]
# Epoch 4:  96%|█████████▌| 140/146 [01:12<00:03,  1.92it/s, v_num=0]
# Epoch 4: 100%|██████████| 146/146 [01:13<00:00,  1.98it/s, v_num=0]
# Epoch 4: 100%|██████████| 146/146 [01:13<00:00,  1.98it/s, v_num=0]
# Epoch 4: 100%|██████████| 146/146 [01:13<00:00,  1.98it/s, v_num=0]
# Epoch 4:   0%|          | 0/146 [00:00<?, ?it/s, v_num=0]
# Epoch 5:   0%|          | 0/146 [00:00<?, ?it/s, v_num=0]
# Epoch 5:  14%|█▎        | 20/146 [00:02<00:18,  6.93it/s, v_num=0]
# Epoch 5:  14%|█▎        | 20/146 [00:02<00:18,  6.93it/s, v_num=0]
# Epoch 5:  27%|██▋       | 40/146 [00:05<00:15,  6.97it/s, v_num=0]
# Epoch 5:  27%|██▋       | 40/146 [00:05<00:15,  6.96it/s, v_num=0]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 24.78it/s]
#
#
# Epoch 5:  27%|██▋       | 40/146 [00:07<00:19,  5.34it/s, v_num=0]Epoch 5, global step 780: 'val/nll' was not in top 1
#
# Epoch 5:  41%|████      | 60/146 [00:56<01:20,  1.07it/s, v_num=0]
# Epoch 5:  41%|████      | 60/146 [00:56<01:20,  1.07it/s, v_num=0]
# Epoch 5:  41%|████      | 60/146 [00:57<01:22,  1.04it/s, v_num=0]`Trainer.fit` stopped: `max_steps=800` reached.
#
# Epoch 5:  41%|████      | 60/146 [00:57<01:22,  1.04it/s, v_num=0]
#
#
# $ /usr/bin/python3 -u bd3lms/main.py mode=train data=lm1b-wrap data.cache_dir=/content/bd3lms/data data.streaming=true data.max_train_samples=5000 model=tiny model.length=128 model.attn_backend=sdpa algo=bd3lm trainer.accelerator=gpu trainer.devices=1 trainer.num_nodes=1 trainer.precision=16-mixed trainer.num_sanity_val_steps=0 trainer.log_every_n_steps=10 trainer.val_check_interval=50 trainer.max_steps=800 data.max_valid_samples=100 data.max_test_samples=100 checkpointing.save_dir=/content/repro_runs/bd3lm_finetune_Lp16 checkpointing.resume_from_ckpt=false wandb=null loader.global_batch_size=8 loader.eval_global_batch_size=8 loader.batch_size=8 loader.eval_batch_size=8 loader.num_workers=2 trainer.accumulate_grad_batches=1 block_size=16 training.from_pretrained=/content/repro_runs/bd3lm_base_len128/checkpoints/last.ckpt training.resample=true algo.var_min=false algo.clip_search_widths=[]
# <00:15,  6.91it/s, v_num=0]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 24.15it/s]
#
#
# Epoch 4:  27%|██▋       | 40/146 [00:07<00:19,  5.32it/s, v_num=0]Epoch 4, global step 584: 'val/nll' reached 8.26183 (best 8.26183), saving model to '/content/repro_runs/bd3lm_finetune_Lp16/checkpoints/best.ckpt' as top 1
#
# Epoch 4:  41%|████      | 60/146 [00:44<01:04,  1.33it/s, v_num=0]
# Epoch 4:  41%|████      | 60/146 [00:44<01:04,  1.33it/s, v_num=0]
# Epoch 4:  55%|█████▍    | 80/146 [00:47<00:39,  1.67it/s, v_num=0]
# Epoch 4:  55%|█████▍    | 80/146 [00:47<00:39,  1.67it/s, v_num=0]
# Epoch 4:  68%|██████▊   | 100/146 [00:50<00:23,  1.97it/s, v_num=0]
# Epoch 4:  68%|██████▊   | 100/146 [00:50<00:23,  1.97it/s, v_num=0]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 24.30it/s]
#
#
# Epoch 4:  68%|██████▊   | 100/146 [00:51<00:23,  1.96it/s, v_num=0]Epoch 4, global step 634: 'val/nll' was not in top 1
#
# Epoch 4:  82%|████████▏ | 120/146 [01:02<00:13,  1.93it/s, v_num=0]
# Epoch 4:  82%|████████▏ | 120/146 [01:02<00:13,  1.93it/s, v_num=0]
# Epoch 4:  96%|█████████▌| 140/146 [01:05<00:02,  2.15it/s, v_num=0]
# Epoch 4:  96%|█████████▌| 140/146 [01:05<00:02,  2.15it/s, v_num=0]
# Epoch 4: 100%|██████████| 146/146 [01:05<00:00,  2.22it/s, v_num=0]
# Epoch 4: 100%|██████████| 146/146 [01:05<00:00,  2.22it/s, v_num=0]
# Epoch 4: 100%|██████████| 146/146 [01:05<00:00,  2.22it/s, v_num=0]
# Epoch 4:   0%|          | 0/146 [00:00<?, ?it/s, v_num=0]
# Epoch 5:   0%|          | 0/146 [00:00<?, ?it/s, v_num=0]
# Epoch 5:  14%|█▎        | 20/146 [00:02<00:18,  6.92it/s, v_num=0]
# Epoch 5:  14%|█▎        | 20/146 [00:02<00:18,  6.92it/s, v_num=0]
# Epoch 5:  27%|██▋       | 40/146 [00:05<00:15,  6.82it/s, v_num=0]
# Epoch 5:  27%|██▋       | 40/146 [00:05<00:15,  6.82it/s, v_num=0]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 24.04it/s]
#
#
# Epoch 5:  27%|██▋       | 40/146 [00:07<00:20,  5.26it/s, v_num=0]Epoch 5, global step 730: 'val/nll' reached 8.24315 (best 8.24315), saving model to '/content/repro_runs/bd3lm_finetune_Lp16/checkpoints/best.ckpt' as top 1
#
# Epoch 5:  41%|████      | 60/146 [00:20<00:29,  2.95it/s, v_num=0]
# Epoch 5:  41%|████      | 60/146 [00:20<00:29,  2.95it/s, v_num=0]
# Epoch 5:  55%|█████▍    | 80/146 [00:23<00:19,  3.46it/s, v_num=0]
# Epoch 5:  55%|█████▍    | 80/146 [00:23<00:19,  3.46it/s, v_num=0]
# Epoch 5:  68%|██████▊   | 100/146 [00:25<00:11,  3.85it/s, v_num=0]
# Epoch 5:  68%|██████▊   | 100/146 [00:25<00:11,  3.85it/s, v_num=0]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 23.96it/s]
#
#
# Epoch 5:  68%|██████▊   | 100/146 [00:26<00:12,  3.80it/s, v_num=0]Epoch 5, global step 780: 'val/nll' was not in top 1
#
# Epoch 5:  82%|████████▏ | 120/146 [00:39<00:08,  3.05it/s, v_num=0]
# Epoch 5:  82%|████████▏ | 120/146 [00:39<00:08,  3.05it/s, v_num=0]
# Epoch 5:  82%|████████▏ | 120/146 [00:39<00:08,  3.05it/s, v_num=0]`Trainer.fit` stopped: `max_steps=800` reached.
#
# Epoch 5:  82%|████████▏ | 120/146 [00:39<00:08,  3.05it/s, v_num=0]
#
#
# $ /usr/bin/python3 -u bd3lms/main.py mode=ppl_eval data=lm1b-wrap data.cache_dir=/content/bd3lms/data data.streaming=true data.max_test_samples=1000 model=tiny model.length=128 model.attn_backend=sdpa algo=bd3lm eval.checkpoint_path=/content/repro_runs/bd3lm_finetune_Lp16/checkpoints/last.ckpt trainer.accelerator=gpu trainer.devices=1 trainer.num_nodes=1 trainer.precision=16-mixed trainer.num_sanity_val_steps=0 wandb=null loader.global_batch_size=8 loader.eval_global_batch_size=8 loader.batch_size=8 loader.eval_batch_size=8 loader.num_workers=2 trainer.accumulate_grad_batches=1 block_size=16 algo.var_min=false
# _test_bs128_wrapped.dat
# [2026-01-23 23:17:38,804][dataloader][INFO] - streaming=True
#
# ============================================================
# GET_STREAMING_SAMPLES DEBUG: lm1b
#   Requested: 1000 samples
#   Input type: <class 'datasets.iterable_dataset.IterableDataset'>
#   Returning dataset with 1000 samples
# ============================================================
#
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Map: 100%|██████████| 1000/1000 [00:00<00:00, 2358.61 examples/s]
# Map: 100%|██████████| 1000/1000 [00:00<00:00, 2350.77 examples/s]
#
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Map: 100%|██████████| 1000/1000 [00:00<00:00, 40754.63 examples/s]
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 1 processes
# ----------------------------------------------------------------------------------------------------
#
# 2026-01-23 23:19:23.698433: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769210363.727356    6851 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769210363.735969    6851 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769210363.757725    6851 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769210363.757761    6851 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769210363.757769    6851 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769210363.757777    6851 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-23 23:19:23.763867: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/connectors/data_connector.py:476: Your `val_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
# /usr/local/lib/python3.12/dist-packages/torch/distributed/distributed_c10d.py:4631: UserWarning: No device id is provided via `init_process_group` or `barrier `. Using the current device set by the user.
#   warnings.warn(  # warn only once
#
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/29 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/29 [00:00<?, ?it/s]
# Validation DataLoader 0:  69%|██████▉   | 20/29 [00:01<00:00, 13.40it/s]
# Validation DataLoader 0: 100%|██████████| 29/29 [00:01<00:00, 15.25it/s]
# Validation DataLoader 0: 100%|██████████| 29/29 [00:01<00:00, 14.94it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val/bpd          │    15.695613861083984     │
# │          val/nll          │     10.87937068939209     │
# │          val/ppl          │      53070.19140625       │
# └───────────────────────────┴───────────────────────────┘
#
#
# $ /usr/bin/python3 -u bd3lms/main.py mode=train data=lm1b-wrap data.cache_dir=/content/bd3lms/data data.streaming=true data.max_train_samples=5000 model=tiny model.length=128 model.attn_backend=sdpa algo=bd3lm trainer.accelerator=gpu trainer.devices=1 trainer.num_nodes=1 trainer.precision=16-mixed trainer.num_sanity_val_steps=0 trainer.log_every_n_steps=10 trainer.val_check_interval=50 trainer.max_steps=800 data.max_valid_samples=100 data.max_test_samples=100 checkpointing.save_dir=/content/repro_runs/bd3lm_finetune_Lp8 checkpointing.resume_from_ckpt=false wandb=null loader.global_batch_size=8 loader.eval_global_batch_size=8 loader.batch_size=8 loader.eval_batch_size=8 loader.num_workers=2 trainer.accumulate_grad_batches=1 block_size=8 training.from_pretrained=/content/repro_runs/bd3lm_base_len128/checkpoints/last.ckpt training.resample=true algo.var_min=false algo.clip_search_widths=[]
#  [00:02<00:18,  6.90it/s, v_num=0]
# Epoch 4:  14%|█▎        | 20/146 [00:02<00:18,  6.90it/s, v_num=0]
# Epoch 4:  27%|██▋       | 40/146 [00:05<00:15,  6.95it/s, v_num=0]
# Epoch 4:  27%|██▋       | 40/146 [00:05<00:15,  6.95it/s, v_num=0]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 24.16it/s]
#
#
# Epoch 4:  27%|██▋       | 40/146 [00:07<00:19,  5.33it/s, v_num=0]Epoch 4, global step 584: 'val/nll' was not in top 1
#
# Epoch 4:  41%|████      | 60/146 [00:13<00:19,  4.39it/s, v_num=0]
# Epoch 4:  41%|████      | 60/146 [00:13<00:19,  4.39it/s, v_num=0]
# Epoch 4:  55%|█████▍    | 80/146 [00:16<00:13,  4.84it/s, v_num=0]
# Epoch 4:  55%|█████▍    | 80/146 [00:16<00:13,  4.84it/s, v_num=0]
# Epoch 4:  68%|██████▊   | 100/146 [00:19<00:08,  5.16it/s, v_num=0]
# Epoch 4:  68%|██████▊   | 100/146 [00:19<00:08,  5.16it/s, v_num=0]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 24.13it/s]
#
#
# Epoch 4:  68%|██████▊   | 100/146 [00:19<00:09,  5.08it/s, v_num=0]Epoch 4, global step 634: 'val/nll' was not in top 1
#
# Epoch 4:  82%|████████▏ | 120/146 [00:24<00:05,  4.81it/s, v_num=0]
# Epoch 4:  82%|████████▏ | 120/146 [00:24<00:05,  4.81it/s, v_num=0]
# Epoch 4:  96%|█████████▌| 140/146 [00:27<00:01,  5.04it/s, v_num=0]
# Epoch 4:  96%|█████████▌| 140/146 [00:27<00:01,  5.04it/s, v_num=0]
# Epoch 4: 100%|██████████| 146/146 [00:28<00:00,  5.10it/s, v_num=0]
# Epoch 4: 100%|██████████| 146/146 [00:28<00:00,  5.10it/s, v_num=0]
# Epoch 4: 100%|██████████| 146/146 [00:28<00:00,  5.10it/s, v_num=0]
# Epoch 4:   0%|          | 0/146 [00:00<?, ?it/s, v_num=0]
# Epoch 5:   0%|          | 0/146 [00:00<?, ?it/s, v_num=0]
# Epoch 5:  14%|█▎        | 20/146 [00:02<00:18,  6.97it/s, v_num=0]
# Epoch 5:  14%|█▎        | 20/146 [00:02<00:18,  6.97it/s, v_num=0]
# Epoch 5:  27%|██▋       | 40/146 [00:05<00:15,  6.98it/s, v_num=0]
# Epoch 5:  27%|██▋       | 40/146 [00:05<00:15,  6.98it/s, v_num=0]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 19.85it/s]
#
#
# Epoch 5:  27%|██▋       | 40/146 [00:07<00:20,  5.23it/s, v_num=0]Epoch 5, global step 730: 'val/nll' was not in top 1
#
# Epoch 5:  41%|████      | 60/146 [00:50<01:11,  1.19it/s, v_num=0]
# Epoch 5:  41%|████      | 60/146 [00:50<01:11,  1.19it/s, v_num=0]
# Epoch 5:  55%|█████▍    | 80/146 [00:53<00:43,  1.51it/s, v_num=0]
# Epoch 5:  55%|█████▍    | 80/146 [00:53<00:43,  1.51it/s, v_num=0]
# Epoch 5:  68%|██████▊   | 100/146 [00:56<00:25,  1.79it/s, v_num=0]
# Epoch 5:  68%|██████▊   | 100/146 [00:56<00:25,  1.79it/s, v_num=0]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 25.29it/s]
#
#
# Epoch 5:  68%|██████▊   | 100/146 [00:56<00:25,  1.78it/s, v_num=0]Epoch 5, global step 780: 'val/nll' was not in top 1
#
# Epoch 5:  82%|████████▏ | 120/146 [01:04<00:13,  1.87it/s, v_num=0]
# Epoch 5:  82%|████████▏ | 120/146 [01:04<00:13,  1.87it/s, v_num=0]
# Epoch 5:  82%|████████▏ | 120/146 [01:04<00:13,  1.87it/s, v_num=0]`Trainer.fit` stopped: `max_steps=800` reached.
#
# Epoch 5:  82%|████████▏ | 120/146 [01:04<00:13,  1.87it/s, v_num=0]
#
#
# $ /usr/bin/python3 -u bd3lms/main.py mode=ppl_eval data=lm1b-wrap data.cache_dir=/content/bd3lms/data data.streaming=true data.max_test_samples=1000 model=tiny model.length=128 model.attn_backend=sdpa algo=bd3lm eval.checkpoint_path=/content/repro_runs/bd3lm_finetune_Lp8/checkpoints/last.ckpt trainer.accelerator=gpu trainer.devices=1 trainer.num_nodes=1 trainer.precision=16-mixed trainer.num_sanity_val_steps=0 wandb=null loader.global_batch_size=8 loader.eval_global_batch_size=8 loader.batch_size=8 loader.eval_batch_size=8 loader.num_workers=2 trainer.accumulate_grad_batches=1 block_size=8 algo.var_min=false
# _test_bs128_wrapped.dat
# [2026-01-23 23:27:48,793][dataloader][INFO] - streaming=True
#
# ============================================================
# GET_STREAMING_SAMPLES DEBUG: lm1b
#   Requested: 1000 samples
#   Input type: <class 'datasets.iterable_dataset.IterableDataset'>
#   Returning dataset with 1000 samples
# ============================================================
#
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Map: 100%|██████████| 1000/1000 [00:00<00:00, 2392.01 examples/s]
# Map: 100%|██████████| 1000/1000 [00:00<00:00, 2384.12 examples/s]
#
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Map: 100%|██████████| 1000/1000 [00:00<00:00, 37697.54 examples/s]
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 1 processes
# ----------------------------------------------------------------------------------------------------
#
# 2026-01-23 23:29:38.303736: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769210978.321093    9611 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769210978.326143    9611 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769210978.339858    9611 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769210978.339880    9611 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769210978.339883    9611 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769210978.339885    9611 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-23 23:29:38.343994: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/connectors/data_connector.py:476: Your `val_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
# /usr/local/lib/python3.12/dist-packages/torch/distributed/distributed_c10d.py:4631: UserWarning: No device id is provided via `init_process_group` or `barrier `. Using the current device set by the user.
#   warnings.warn(  # warn only once
#
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/29 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/29 [00:00<?, ?it/s]
# Validation DataLoader 0:  69%|██████▉   | 20/29 [00:01<00:00, 13.91it/s]
# Validation DataLoader 0: 100%|██████████| 29/29 [00:01<00:00, 15.74it/s]
# Validation DataLoader 0: 100%|██████████| 29/29 [00:01<00:00, 15.51it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val/bpd          │     35.06770706176758     │
# │          val/nll          │    24.307083129882812     │
# │          val/ppl          │       36010741760.0       │
# └───────────────────────────┴───────────────────────────┘
#
#
# $ /usr/bin/python3 -u bd3lms/main.py mode=train data=lm1b-wrap data.cache_dir=/content/bd3lms/data data.streaming=true data.max_train_samples=5000 model=tiny model.length=128 model.attn_backend=sdpa algo=bd3lm trainer.accelerator=gpu trainer.devices=1 trainer.num_nodes=1 trainer.precision=16-mixed trainer.num_sanity_val_steps=0 trainer.log_every_n_steps=10 trainer.val_check_interval=50 trainer.max_steps=800 data.max_valid_samples=100 data.max_test_samples=100 checkpointing.save_dir=/content/repro_runs/bd3lm_finetune_Lp4 checkpointing.resume_from_ckpt=false wandb=null loader.global_batch_size=8 loader.eval_global_batch_size=8 loader.batch_size=8 loader.eval_batch_size=8 loader.num_workers=2 trainer.accumulate_grad_batches=1 block_size=4 training.from_pretrained=/content/repro_runs/bd3lm_base_len128/checkpoints/last.ckpt training.resample=true algo.var_min=false algo.clip_search_widths=[]
#  [00:02<00:18,  6.74it/s, v_num=0]
# Epoch 4:  14%|█▎        | 20/146 [00:02<00:18,  6.74it/s, v_num=0]
# Epoch 4:  27%|██▋       | 40/146 [00:05<00:15,  6.84it/s, v_num=0]
# Epoch 4:  27%|██▋       | 40/146 [00:05<00:15,  6.84it/s, v_num=0]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 23.98it/s]
#
#
# Epoch 4:  27%|██▋       | 40/146 [00:07<00:20,  5.26it/s, v_num=0]Epoch 4, global step 584: 'val/nll' was not in top 1
#
# Epoch 4:  41%|████      | 60/146 [01:01<01:28,  0.97it/s, v_num=0]
# Epoch 4:  41%|████      | 60/146 [01:01<01:28,  0.97it/s, v_num=0]
# Epoch 4:  55%|█████▍    | 80/146 [01:04<00:53,  1.23it/s, v_num=0]
# Epoch 4:  55%|█████▍    | 80/146 [01:04<00:53,  1.23it/s, v_num=0]
# Epoch 4:  68%|██████▊   | 100/146 [01:07<00:31,  1.48it/s, v_num=0]
# Epoch 4:  68%|██████▊   | 100/146 [01:07<00:31,  1.48it/s, v_num=0]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 24.92it/s]
#
#
# Epoch 4:  68%|██████▊   | 100/146 [01:08<00:31,  1.47it/s, v_num=0]Epoch 4, global step 634: 'val/nll' was not in top 1
#
# Epoch 4:  82%|████████▏ | 120/146 [01:12<00:15,  1.65it/s, v_num=0]
# Epoch 4:  82%|████████▏ | 120/146 [01:12<00:15,  1.65it/s, v_num=0]
# Epoch 4:  96%|█████████▌| 140/146 [01:15<00:03,  1.85it/s, v_num=0]
# Epoch 4:  96%|█████████▌| 140/146 [01:15<00:03,  1.85it/s, v_num=0]
# Epoch 4: 100%|██████████| 146/146 [01:16<00:00,  1.91it/s, v_num=0]
# Epoch 4: 100%|██████████| 146/146 [01:16<00:00,  1.91it/s, v_num=0]
# Epoch 4: 100%|██████████| 146/146 [01:16<00:00,  1.91it/s, v_num=0]
# Epoch 4:   0%|          | 0/146 [00:00<?, ?it/s, v_num=0]
# Epoch 5:   0%|          | 0/146 [00:00<?, ?it/s, v_num=0]
# Epoch 5:  14%|█▎        | 20/146 [00:02<00:18,  6.94it/s, v_num=0]
# Epoch 5:  14%|█▎        | 20/146 [00:02<00:18,  6.94it/s, v_num=0]
# Epoch 5:  27%|██▋       | 40/146 [00:05<00:15,  6.81it/s, v_num=0]
# Epoch 5:  27%|██▋       | 40/146 [00:05<00:15,  6.81it/s, v_num=0]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 24.23it/s]
#
#
# Epoch 5:  27%|██▋       | 40/146 [00:07<00:20,  5.22it/s, v_num=0]Epoch 5, global step 730: 'val/nll' was not in top 1
#
# Epoch 5:  41%|████      | 60/146 [00:11<00:16,  5.11it/s, v_num=0]
# Epoch 5:  41%|████      | 60/146 [00:11<00:16,  5.11it/s, v_num=0]
# Epoch 5:  55%|█████▍    | 80/146 [00:14<00:12,  5.47it/s, v_num=0]
# Epoch 5:  55%|█████▍    | 80/146 [00:14<00:12,  5.47it/s, v_num=0]
# Epoch 5:  68%|██████▊   | 100/146 [00:17<00:08,  5.70it/s, v_num=0]
# Epoch 5:  68%|██████▊   | 100/146 [00:17<00:08,  5.70it/s, v_num=0]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 22.48it/s]
#
#
# Epoch 5:  68%|██████▊   | 100/146 [00:17<00:08,  5.57it/s, v_num=0]Epoch 5, global step 780: 'val/nll' was not in top 1
#
# Epoch 5:  82%|████████▏ | 120/146 [01:16<00:16,  1.58it/s, v_num=0]
# Epoch 5:  82%|████████▏ | 120/146 [01:16<00:16,  1.58it/s, v_num=0]
# Epoch 5:  82%|████████▏ | 120/146 [01:16<00:16,  1.58it/s, v_num=0]`Trainer.fit` stopped: `max_steps=800` reached.
#
# Epoch 5:  82%|████████▏ | 120/146 [01:16<00:16,  1.58it/s, v_num=0]
#
#
# $ /usr/bin/python3 -u bd3lms/main.py mode=ppl_eval data=lm1b-wrap data.cache_dir=/content/bd3lms/data data.streaming=true data.max_test_samples=1000 model=tiny model.length=128 model.attn_backend=sdpa algo=bd3lm eval.checkpoint_path=/content/repro_runs/bd3lm_finetune_Lp4/checkpoints/last.ckpt trainer.accelerator=gpu trainer.devices=1 trainer.num_nodes=1 trainer.precision=16-mixed trainer.num_sanity_val_steps=0 wandb=null loader.global_batch_size=8 loader.eval_global_batch_size=8 loader.batch_size=8 loader.eval_batch_size=8 loader.num_workers=2 trainer.accumulate_grad_batches=1 block_size=4 algo.var_min=false
# _test_bs128_wrapped.dat
# [2026-01-23 23:40:31,503][dataloader][INFO] - streaming=True
#
# ============================================================
# GET_STREAMING_SAMPLES DEBUG: lm1b
#   Requested: 1000 samples
#   Input type: <class 'datasets.iterable_dataset.IterableDataset'>
#   Returning dataset with 1000 samples
# ============================================================
#
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Map: 100%|██████████| 1000/1000 [00:00<00:00, 2389.94 examples/s]
# Map: 100%|██████████| 1000/1000 [00:00<00:00, 2380.63 examples/s]
#
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Map: 100%|██████████| 1000/1000 [00:00<00:00, 38881.15 examples/s]
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 1 processes
# ----------------------------------------------------------------------------------------------------
#
# 2026-01-23 23:42:21.054939: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769211741.072264   12970 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769211741.077319   12970 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769211741.092240   12970 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769211741.092260   12970 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769211741.092262   12970 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769211741.092266   12970 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-23 23:42:21.096303: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/connectors/data_connector.py:476: Your `val_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
# /usr/local/lib/python3.12/dist-packages/torch/distributed/distributed_c10d.py:4631: UserWarning: No device id is provided via `init_process_group` or `barrier `. Using the current device set by the user.
#   warnings.warn(  # warn only once
#
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/29 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/29 [00:00<?, ?it/s]
# Validation DataLoader 0:  69%|██████▉   | 20/29 [00:01<00:00, 13.75it/s]
# Validation DataLoader 0: 100%|██████████| 29/29 [00:01<00:00, 15.63it/s]
# Validation DataLoader 0: 100%|██████████| 29/29 [00:01<00:00, 15.37it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val/bpd          │    21.192352294921875     │
# │          val/nll          │    14.689419746398926     │
# │          val/ppl          │         2396260.0         │
# └───────────────────────────┴───────────────────────────┘

# %%
def print_table(rows):
    if not rows:
        print("No data to display.")
        return

    columns = list(rows[0].keys())

    str_rows = [
        {col: str(row.get(col, "")) for col in columns}
        for row in rows
    ]

    widths = {
        col: max(len(col), max(len(row[col]) for row in str_rows))
        for col in columns
    }

    def print_separator():
        print("+" + "+".join("-" * (widths[col] + 2) for col in columns) + "+")

    def print_row(row):
        print(
            "| " +
            " | ".join(row[col].ljust(widths[col]) for col in columns) +
            " |"
        )

    # Print table
    print_separator()
    print_row({col: col for col in columns})
    print_separator()
    for row in str_rows:
        print_row(row)
    print_separator()

print_table(results)
# Out:
# +-------------------------+-------------------+----------------+
# | model                   | block_size_Lprime | val_ppl        |
# +-------------------------+-------------------+----------------+
# | Block diffusion (BD3LM) | 16                | 53070.19140625 |
# | Block diffusion (BD3LM) | 8                 | 36010741760.0  |
# | Block diffusion (BD3LM) | 4                 | 2396260.0      |
# +-------------------------+-------------------+----------------+
